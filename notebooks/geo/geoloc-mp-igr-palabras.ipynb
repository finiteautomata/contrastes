# %% [markdown]
# # Geolocalización con MultiProcessing + IGR Palabras
#
# En esta notebook haremos un intento de geolocalización con los textos de los usuarios...

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd

df_train = pd.read_json("../data/geoloc/users_train.json")
df_test = pd.read_json("../data/geoloc/users_test.json")

# %% [markdown]
# Hagamos lo siguiente:
#
# - Entrenemos con unigramas una regresión logística para
# - Luego probemos con los regionalismos
#
# Primero, partamos en train, test

# %%
df_train.groupby("provincia").count()
# Out:
#                 text
# provincia
# buenosaires      337
# catamarca        341
# chaco            331
# chubut           328
# cordoba          317
# corrientes       345
# entrerios        338
# formosa          286
# jujuy            339
# lapampa          324
# larioja          306
# mendoza          326
# misiones         327
# neuquen          350
# rionegro         313
# salta            346
# sanjuan          326
# sanluis          321
# santacruz        288
# santafe          347
# santiago         294
# tierradelfuego   332
# tucuman          338

# %% [markdown]
# ## Palabras precalculadas
#
# Carguemos antes las palabras que sabemos que ocurren una cantidad razonable de veces

# %%
# %%time
from contrastes.processing import build_dataframe_from_users
from contrastes.processing import preprocess_raw_df


#word_df = build_dataframe_from_users(row for index, row in df_train.iterrows())

word_df = pd.read_csv("train_word_df_filtered.csv", index_col=0)
word_df = preprocess_raw_df(word_df, filter_words=(10, 2))
# Out:
# CPU times: user 1.45 s, sys: 220 ms, total: 1.67 s
# Wall time: 1.67 s
# /home/jmperez/projects/contrastes/contrastes/processing.py:185: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnas_palabras = cant_palabras
# /home/jmperez/projects/contrastes/contrastes/processing.py:186: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnas_personas = cant_personas

# %% [markdown]
# La reg. logística será un softmax, así que elijo `multi_class='multinomial'`

# %%
from contrastes.igr import igr

word_df["igr"] = igr(word_df, word_df.columnas_palabras)

# %%
word_df.sort_values("igr", ascending=False, inplace=True)

word_df[:30][word_df.columnas_palabras]
# Out:
#              buenosaires_ocurrencias  catamarca_ocurrencias  \
# rioja                           21.0                  219.0
# logroño                          0.0                    0.0
# hoa                              0.0                    1.0
# ushuaia                         19.0                    2.0
# chepes                           0.0                    0.0
# tiemposur                        0.0                    0.0
# palpala                          0.0                    0.0
# beder                            0.0                    0.0
# quitilipi                        0.0                    0.0
# oberá                            0.0                    1.0
# chivilcoy                     2331.0                    0.0
# jujuy                           17.0                   53.0
# asprodema                        0.0                    0.0
# graty                            0.0                    0.0
# calahorra                        0.0                    0.0
# chilecito                        0.0                    6.0
# riojanos                         0.0                    7.0
# canicross                        0.0                    0.0
# tdf                              1.0                    0.0
# bragado                       1757.0                    0.0
# tilly                            0.0                    0.0
# biosfera                         0.0                    0.0
# riojana                          2.0                    9.0
# quintela                         0.0                    0.0
# antihumedad                      0.0                    0.0
# nájera                           0.0                    0.0
# palpalá                          0.0                    0.0
# adosac                           0.0                    0.0
# psoe                             0.0                    0.0
# rada                             0.0                    1.0
#
#              chaco_ocurrencias  chubut_ocurrencias  cordoba_ocurrencias  \
# rioja                      3.0                18.0                 23.0
# logroño                    0.0                 0.0                  0.0
# rioja                         10.0                 45.0                  11.0
# logroño                        0.0                  0.0                   0.0
# hoa                            2.0                  0.0                   0.0
# ushuaia                       35.0                  6.0                  14.0
# chepes                         0.0                  0.0                   0.0
# tiemposur                    883.0                  0.0                   0.0
# palpala                        0.0                  0.0                   2.0
# beder                          1.0                  0.0                   0.0
# quitilipi                      0.0                  0.0                   0.0
# oberá                          2.0                  1.0                   0.0
# chivilcoy                      0.0                  0.0                   0.0
# jujuy                         67.0                 23.0                  29.0
# asprodema                      0.0                  0.0                   0.0
# graty                          0.0                  2.0                   0.0
# calahorra                      0.0                  0.0                   0.0
# chilecito                      1.0                  0.0                   0.0
# riojanos                       1.0                  0.0                   0.0
# canicross                      0.0                  0.0                   0.0
# tdf                           12.0                  0.0                   0.0
# bragado                        0.0                  4.0                   0.0
# tilly                          6.0                  1.0                   0.0
# biosfera                       0.0                  0.0                   0.0
# riojana                        0.0                  2.0                   0.0
# quintela                       0.0                  0.0                   0.0
# antihumedad                    0.0                  0.0                   0.0
# nájera                         0.0                  0.0                   0.0
# palpalá                        0.0                  0.0                   0.0
# adosac                       386.0                  0.0                   0.0
# psoe                           1.0                  0.0                   0.0
# rada                           9.0                  6.0                   2.0
#
#              tierradelfuego_ocurrencias  tucuman_ocurrencias
# rioja                               4.0                 44.0
# logroño                             0.0                  0.0
# hoa                                 0.0                  0.0
# ushuaia                          5640.0                  2.0
# chepes                              0.0                  0.0
# tiemposur                           0.0                  0.0
# palpala                             0.0                  0.0
# beder                               0.0                  0.0
# quitilipi                           0.0                  0.0
# oberá                               1.0                  1.0
# chivilcoy                           1.0                  0.0
# jujuy                              21.0                132.0
# asprodema                           0.0                  0.0
# graty                               0.0                  0.0
# calahorra                           0.0                  0.0
# chilecito                           1.0                  3.0
# riojanos                            2.0                  0.0
# canicross                           0.0                  0.0
# tdf                              1374.0                  0.0
# bragado                             0.0                  0.0
# tilly                               5.0                  0.0
# biosfera                            0.0                  0.0
# riojana                             2.0                  1.0
# quintela                            0.0                  0.0
# antihumedad                         0.0                  1.0
# nájera                              0.0                  0.0
# palpalá                             0.0                  0.0
# adosac                              0.0                  0.0
# psoe                                0.0                  0.0
# rada                                9.0                  4.0
#
# [30 rows x 23 columns]

# %% [markdown]
# Veamos qué performance tiene usando 1000, 2000, 3000, y así...

# %%
# %%time
from sklearn.feature_extraction.text import CountVectorizer
from contrastes.text import tokenize

liw_vectorizer = CountVectorizer(
    tokenizer=tokenize,
    vocabulary=word_df.index)

X_train = liw_vectorizer.fit_transform(df_train["text"])
print("Vectorizing")
X_test = liw_vectorizer.transform(df_test["text"])
# Out:
# Vectorizing
# CPU times: user 10min 22s, sys: 1.34 s, total: 10min 23s
# Wall time: 10min 24s

# %% [markdown]
# Ya las tenemos vectorizadas en el orden esperado!

# %%
from sklearn.preprocessing import LabelEncoder

province_encoder = LabelEncoder()

province_encoder.fit(df_train["provincia"].values)

y_train = province_encoder.transform(df_train["provincia"].values)
y_test = province_encoder.transform(df_test["provincia"].values)

# %%
# %%time
from contrastes.classifiers import fit_classifiers

num_words_to_fit = list(range(250, 5000, 250)) + list(range(5000, 20000, 500))

ret = fit_classifiers(X_train, y_train, X_test, y_test, 
                      province_encoder=province_encoder,
                      range_num_words=num_words_to_fit, num_jobs=8)
# Out:
# Entrenando con 750 palabras
# Entrenando con 3750 palabras
# Entrenando con 1250 palabras
# Entrenando con 1750 palabras
# Entrenando con 2750 palabras
# Entrenando con 2250 palabras
# Entrenando con 3250 palabras
# Entrenando con 250 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 250   palabras ----> accuracy 42.12 mean distance 592.5516
# Entrenando con 500 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 1250  palabras ----> accuracy 60.24 mean distance 401.956
# Entrenando con 1500 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 2250  palabras ----> accuracy 63.92 mean distance 335.9632
# Entrenando con 2500 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 1750  palabras ----> accuracy 63.16 mean distance 351.1988
# Entrenando con 2000 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 2750  palabras ----> accuracy 66.56 mean distance 252.6876
# Entrenando con 3000 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 3750  palabras ----> accuracy 68.12 mean distance 245.236
# Entrenando con 4000 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 750   palabras ----> accuracy 56.80 mean distance 436.3248
# Entrenando con 1000 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 3250  palabras ----> accuracy 66.92 mean distance 255.4844
# Entrenando con 3500 palabras
# 500   palabras ----> accuracy 51.20 mean distance 502.8532
# Entrenando con 4250 palabras
# 1500  palabras ----> accuracy 62.20 mean distance 377.0852
# Entrenando con 4750 palabras
# 2500  palabras ----> accuracy 65.92 mean distance 260.6856
# Entrenando con 5500 palabras
# 2000  palabras ----> accuracy 63.88 mean distance 344.4592
# Entrenando con 6500 palabras
# 1000  palabras ----> accuracy 59.04 mean distance 411.2016
# Entrenando con 7500 palabras
# 3000  palabras ----> accuracy 66.76 mean distance 253.7084
# Entrenando con 8500 palabras
# 3500  palabras ----> accuracy 67.48 mean distance 251.1044
# Entrenando con 9500 palabras
# 4000  palabras ----> accuracy 68.88 mean distance 240.814
# Entrenando con 10500 palabras
# 4250  palabras ----> accuracy 69.68 mean distance 237.0436
# Entrenando con 4500 palabras
# 4750  palabras ----> accuracy 69.60 mean distance 240.2368
# Entrenando con 5000 palabras
# 5500  palabras ----> accuracy 66.96 mean distance 322.3436
# Entrenando con 6000 palabras
# 6500  palabras ----> accuracy 67.92 mean distance 313.8024
# Entrenando con 7000 palabras
# 7500  palabras ----> accuracy 65.40 mean distance 354.0352
# Entrenando con 8000 palabras
# 4500  palabras ----> accuracy 69.56 mean distance 240.3576
# Entrenando con 11500 palabras
# 8500  palabras ----> accuracy 65.72 mean distance 346.4316
# Entrenando con 9000 palabras
# 5000  palabras ----> accuracy 69.88 mean distance 237.3748
# 9500  palabras ----> accuracy 67.08 mean distance 326.8996
# Entrenando con 10000 palabras
# Entrenando con 12500 palabras
# 10500 palabras ----> accuracy 67.24 mean distance 325.3404
# Entrenando con 11000 palabras
# 6000  palabras ----> accuracy 67.40 mean distance 321.9744
# Entrenando con 13500 palabras
# 7000  palabras ----> accuracy 66.84 mean distance 341.9164
# Entrenando con 14500 palabras
# 8000  palabras ----> accuracy 66.32 mean distance 337.1172
# Entrenando con 15500 palabras
# 9000  palabras ----> accuracy 66.88 mean distance 329.9196
# Entrenando con 16500 palabras
# 11500 palabras ----> accuracy 66.80 mean distance 319.252
# Entrenando con 12000 palabras
# 10000 palabras ----> accuracy 67.04 mean distance 328.0696
# Entrenando con 17500 palabras
# 11000 palabras ----> accuracy 66.84 mean distance 322.3044
# Entrenando con 18500 palabras
# 12500 palabras ----> accuracy 67.00 mean distance 314.0436
# Entrenando con 13000 palabras
# 13500 palabras ----> accuracy 67.84 mean distance 312.3008
# Entrenando con 14000 palabras
# 14500 palabras ----> accuracy 68.56 mean distance 300.7956
# Entrenando con 15000 palabras
# 15500 palabras ----> accuracy 68.92 mean distance 296.7128
# Entrenando con 16000 palabras
# 12000 palabras ----> accuracy 67.12 mean distance 316.0892
# Entrenando con 19500 palabras
# 16500 palabras ----> accuracy 68.92 mean distance 293.7264
# Entrenando con 17000 palabras
# 13000 palabras ----> accuracy 67.76 mean distance 311.6844
# 18500 palabras ----> accuracy 68.20 mean distance 287.1968
# Entrenando con 19000 palabras
# 14000 palabras ----> accuracy 68.52 mean distance 301.4856
# 17500 palabras ----> accuracy 68.36 mean distance 286.2312
# Entrenando con 18000 palabras
# 15000 palabras ----> accuracy 68.76 mean distance 298.1908
# 16000 palabras ----> accuracy 68.80 mean distance 297.1724
# 17000 palabras ----> accuracy 69.12 mean distance 291.8328
# 19500 palabras ----> accuracy 68.28 mean distance 285.4608
# 18000 palabras ----> accuracy 68.36 mean distance 286.39
# 19000 palabras ----> accuracy 68.20 mean distance 287.2796
# CPU times: user 184 ms, sys: 708 ms, total: 892 ms
# Wall time: 1min 16s

# %%
for r in ret:
    num_words = r["num_words"]
    acc = r["accuracy"]
    md = r["mean_distance"]
    print("{:<5} palabras ----> accuracy {:.2f} mean distance {}".format(
        num_words, acc*100, md
    ))
# Out:
# 250   palabras ----> accuracy 42.12 mean distance 592.5516
# 500   palabras ----> accuracy 51.20 mean distance 502.8532
# 750   palabras ----> accuracy 56.80 mean distance 436.3248
# 1000  palabras ----> accuracy 59.04 mean distance 411.2016
# 1250  palabras ----> accuracy 60.24 mean distance 401.956
# 1500  palabras ----> accuracy 62.20 mean distance 377.0852
# 1750  palabras ----> accuracy 63.16 mean distance 351.1988
# 2000  palabras ----> accuracy 63.88 mean distance 344.4592
# 2250  palabras ----> accuracy 63.92 mean distance 335.9632
# 2500  palabras ----> accuracy 65.92 mean distance 260.6856
# 2750  palabras ----> accuracy 66.56 mean distance 252.6876
# 3000  palabras ----> accuracy 66.76 mean distance 253.7084
# 3250  palabras ----> accuracy 66.92 mean distance 255.4844
# 3500  palabras ----> accuracy 67.48 mean distance 251.1044
# 3750  palabras ----> accuracy 68.12 mean distance 245.236
# 4000  palabras ----> accuracy 68.88 mean distance 240.814
# 4250  palabras ----> accuracy 69.68 mean distance 237.0436
# 4500  palabras ----> accuracy 69.56 mean distance 240.3576
# 4750  palabras ----> accuracy 69.60 mean distance 240.2368
# 5000  palabras ----> accuracy 69.88 mean distance 237.3748
# 5500  palabras ----> accuracy 66.96 mean distance 322.3436
# 6000  palabras ----> accuracy 67.40 mean distance 321.9744
# 6500  palabras ----> accuracy 67.92 mean distance 313.8024
# 7000  palabras ----> accuracy 66.84 mean distance 341.9164
# 7500  palabras ----> accuracy 65.40 mean distance 354.0352
# 8000  palabras ----> accuracy 66.32 mean distance 337.1172
# 8500  palabras ----> accuracy 65.72 mean distance 346.4316
# 9000  palabras ----> accuracy 66.88 mean distance 329.9196
# 9500  palabras ----> accuracy 67.08 mean distance 326.8996
# 10000 palabras ----> accuracy 67.04 mean distance 328.0696
# 10500 palabras ----> accuracy 67.24 mean distance 325.3404
# 11000 palabras ----> accuracy 66.84 mean distance 322.3044
# 11500 palabras ----> accuracy 66.80 mean distance 319.252
# 12000 palabras ----> accuracy 67.12 mean distance 316.0892
# 12500 palabras ----> accuracy 67.00 mean distance 314.0436
# 13000 palabras ----> accuracy 67.76 mean distance 311.6844
# 13500 palabras ----> accuracy 67.84 mean distance 312.3008
# 14000 palabras ----> accuracy 68.52 mean distance 301.4856
# 14500 palabras ----> accuracy 68.56 mean distance 300.7956
# 15000 palabras ----> accuracy 68.76 mean distance 298.1908
# 15500 palabras ----> accuracy 68.92 mean distance 296.7128
# 16000 palabras ----> accuracy 68.80 mean distance 297.1724
# 16500 palabras ----> accuracy 68.92 mean distance 293.7264
# 17000 palabras ----> accuracy 69.12 mean distance 291.8328
# 17500 palabras ----> accuracy 68.36 mean distance 286.2312
# 18000 palabras ----> accuracy 68.36 mean distance 286.39
# 18500 palabras ----> accuracy 68.20 mean distance 287.1968
# 19000 palabras ----> accuracy 68.20 mean distance 287.2796
# 19500 palabras ----> accuracy 68.28 mean distance 285.4608

# %%
import pickle

pickle.dump(ret, open("res_igr_palabras.pkl", "wb"))

# %%
new_ret = pickle.load(open("res_igr_palabras.pkl", "rb"))

clf = new_ret[1]["clf"]

clf.coef_.shape
# Out:
# (23, 500)
