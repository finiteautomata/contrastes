# %% [markdown]
# # Geolocalización con MultiProcessing + IGR Personas
#
# En esta notebook haremos un intento de geolocalización con los textos de los usuarios...

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd

df_train = pd.read_json("../data/geoloc/users_train.json")
df_test = pd.read_json("../data/geoloc/users_test.json")

# %% [markdown]
# Hagamos lo siguiente:
#
# - Entrenemos con unigramas una regresión logística para
# - Luego probemos con los regionalismos
#
# Primero, partamos en train, test

# %%
df_train.groupby("provincia").count()
# Out:
#                 text
# provincia
# buenosaires      337
# catamarca        341
# chaco            331
# chubut           328
# cordoba          317
# corrientes       345
# entrerios        338
# formosa          286
# jujuy            339
# lapampa          324
# larioja          306
# mendoza          326
# misiones         327
# neuquen          350
# rionegro         313
# salta            346
# sanjuan          326
# sanluis          321
# santacruz        288
# santafe          347
# santiago         294
# tierradelfuego   332
# tucuman          338

# %% [markdown]
# ## Palabras precalculadas
#
# Carguemos antes las palabras que sabemos que ocurren una cantidad razonable de veces

# %%
# %%time
from contrastes.processing import build_dataframe_from_users
from contrastes.processing import preprocess_raw_df


#word_df = build_dataframe_from_users(row for index, row in df_train.iterrows())

word_df = pd.read_csv("train_word_df_filtered.csv", index_col=0)
word_df = preprocess_raw_df(word_df, filter_words=(10, 2))
# Out:
# CPU times: user 1.02 s, sys: 200 ms, total: 1.22 s
# Wall time: 1.22 s
# /home/jmperez/projects/contrastes/contrastes/processing.py:185: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnas_palabras = cant_palabras
# /home/jmperez/projects/contrastes/contrastes/processing.py:186: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnas_personas = cant_personas

# %% [markdown]
# La reg. logística será un softmax, así que elijo `multi_class='multinomial'`

# %%
from contrastes.igr import igr

word_df["igr"] = igr(word_df, word_df.columnas_personas)

# %%
word_df.sort_values("igr", ascending=False, inplace=True)

word_df[:30][word_df.columnas_palabras]
# Out:
#            buenosaires_ocurrencias  catamarca_ocurrencias  chaco_ocurrencias  \
# bombola                        0.0                    0.0                0.0
# logroño                        0.0                    0.0                0.0
# sanagasta                      0.0                    0.0                0.0
# bombolo                        0.0                    0.0                4.0
# aijue                          0.0                    0.0                0.0
# mitai                          0.0                    0.0                0.0
# aij                            0.0                    0.0                0.0
# fne                            0.0                    0.0                0.0
# unse                           0.0                    0.0                0.0
# quintela                       0.0                    0.0                0.0
# fsa                            0.0                    0.0               22.0
# olta                           0.0                    0.0                0.0
# larioja                        0.0                    0.0                0.0
# calahorra                      0.0                    0.0                0.0
# edese                          0.0                    0.0                0.0
# veril                          0.0                    0.0                0.0
# yarca                          0.0                    0.0                0.0
# breñas                         0.0                    0.0              219.0
# nájera                         0.0                    0.0                0.0
# tineo                          0.0                    0.0                0.0
# mitacuñai                      0.0                    0.0                0.0
# cincue                         0.0                    0.0                0.0
# corvina                        0.0                    0.0                0.0
# chivil                       332.0                    0.0                0.0
# derasore                       0.0                    0.0                0.0
# bombolos                       0.0                    0.0                0.0
# formosaa                       0.0                    0.0                0.0
# chijra                         0.0                    0.0                0.0
# poec                           0.0                    0.0                0.0
# ulapes                         0.0                    0.0                0.0
#
#            chubut_ocurrencias  cordoba_ocurrencias  corrientes_ocurrencias  \
# bombola                   0.0                  0.0                     0.0
# logroño                   0.0                  0.0                     0.0
# sanagasta                 0.0                  0.0                     0.0
# bombolo                   0.0                  0.0                     0.0
# aijue                     0.0                  0.0                     2.0
# mitai                     0.0                  0.0                     7.0
# aij                       0.0                  0.0                     0.0
# fne                       0.0                  0.0                     0.0
# unse                      0.0                  0.0                     0.0
# quintela                  0.0                  0.0                     0.0
# fsa                       0.0                  4.0                     4.0
# olta                      0.0                  0.0                     0.0
# larioja                   0.0                  0.0                     0.0
# calahorra                 0.0                  0.0                     0.0
# edese                     0.0                  0.0                     0.0
# veril                     0.0                  0.0                     0.0
# yarca                     0.0                  0.0                     0.0
# breñas                    0.0                  0.0                     7.0
# nájera                    0.0                  0.0                     0.0
# tineo                     0.0                  0.0                     0.0
# mitacuñai                 0.0                  0.0                     0.0
# cincue                    0.0                  0.0                     0.0
# corvina                   0.0                  0.0                     0.0
# chivil                    0.0                  0.0                     0.0
# derasore                  0.0                  0.0                     0.0
# bombolos                  0.0                  0.0                     0.0
# formosaa                  0.0                  0.0                     0.0
# chijra                    0.0                  0.0                     0.0
# poec                      0.0                  0.0                     0.0
# ulapes                    0.0                  0.0                     0.0
#
#            entrerios_ocurrencias  formosa_ocurrencias  jujuy_ocurrencias  \
# bombola                      0.0                 75.0                0.0
# logroño                      0.0                  0.0                0.0
# sanagasta                    0.0                  0.0                1.0
# bombolo                      0.0                 69.0                0.0
# aijue                        1.0                237.0                0.0
# mitai                        0.0                123.0                0.0
# aij                          0.0                 30.0                0.0
# fne                          0.0                  0.0               75.0
# unse                         0.0                  0.0                0.0
# quintela                     0.0                  0.0                0.0
# fsa                          0.0                282.0                0.0
# olta                         0.0                  0.0                0.0
# larioja                      0.0                  0.0                0.0
# calahorra                    0.0                  0.0                0.0
# edese                        0.0                  0.0                0.0
# veril                        0.0                  0.0                0.0
# yarca                        0.0                  0.0                0.0
# breñas                       0.0                  0.0                0.0
# nájera                       0.0                  0.0                0.0
# tineo                        0.0                  0.0                0.0
# mitacuñai                    0.0                 14.0                0.0
# cincue                       0.0                 43.0                0.0
# corvina                      0.0                 54.0                0.0
# chivil                       0.0                  0.0                0.0
# derasore                     0.0                 17.0                0.0
# bombolos                     0.0                 13.0                0.0
# formosaa                     0.0                 13.0                0.0
# chijra                       0.0                  0.0               31.0
# poec                         0.0                  0.0                0.0
# ulapes                       0.0                  0.0                0.0
#
#            lapampa_ocurrencias         ...           neuquen_ocurrencias  \
# bombola                    0.0         ...                           0.0
# logroño                    0.0         ...                           0.0
# sanagasta                  1.0         ...                           0.0
# bombolo                    0.0         ...                           0.0
# aijue                      0.0         ...                           0.0
# mitai                      0.0         ...                           0.0
# aij                        0.0         ...                           0.0
# fne                        0.0         ...                           0.0
# unse                       0.0         ...                           0.0
# quintela                   0.0         ...                           0.0
# fsa                        0.0         ...                           0.0
# olta                       0.0         ...                           0.0
# larioja                    0.0         ...                           0.0
# calahorra                  0.0         ...                           0.0
# edese                      0.0         ...                           0.0
# veril                      0.0         ...                           0.0
# yarca                      0.0         ...                           0.0
# breñas                     0.0         ...                           0.0
# nájera                     0.0         ...                           0.0
# tineo                      0.0         ...                           0.0
# mitacuñai                  0.0         ...                           0.0
# cincue                     0.0         ...                           0.0
# corvina                    1.0         ...                           0.0
# chivil                     0.0         ...                           0.0
# derasore                   0.0         ...                           0.0
# bombolos                   0.0         ...                           0.0
# formosaa                   0.0         ...                           0.0
# chijra                     0.0         ...                           0.0
# poec                       0.0         ...                         163.0
# ulapes                     0.0         ...                           0.0
#
#            rionegro_ocurrencias  salta_ocurrencias  sanjuan_ocurrencias  \
# bombola                     0.0                0.0                  0.0
# logroño                     0.0                0.0                  0.0
# sanagasta                   0.0                0.0                  0.0
# bombolo                     0.0                0.0                  0.0
# aijue                       0.0                0.0                  0.0
# mitai                       0.0                0.0                  0.0
# aij                         0.0                0.0                  0.0
# fne                         0.0                1.0                  0.0
# unse                        0.0                0.0                  0.0
# quintela                    0.0                0.0                  0.0
# fsa                         0.0                0.0                  0.0
# olta                        0.0                0.0                  0.0
# larioja                     0.0                0.0                  0.0
# calahorra                   0.0                0.0                  0.0
# edese                       0.0                0.0                  0.0
# veril                       0.0                0.0                  0.0
# yarca                       0.0                0.0                160.0
# breñas                      0.0                0.0                  0.0
# nájera                      0.0                0.0                  0.0
# tineo                       0.0                0.0                  0.0
# mitacuñai                   0.0                0.0                  0.0
# cincue                      0.0                0.0                  0.0
# corvina                     1.0                0.0                  0.0
# chivil                      0.0                0.0                  0.0
# derasore                    0.0                0.0                  0.0
# bombolos                    0.0                0.0                  0.0
# formosaa                    0.0                0.0                  0.0
# chijra                      0.0                0.0                  0.0
# poec                        0.0                0.0                  0.0
# ulapes                      0.0                0.0                  0.0
#
#            sanluis_ocurrencias  santacruz_ocurrencias  santafe_ocurrencias  \
# bombola                    0.0                    0.0                  0.0
# logroño                    0.0                    0.0                  0.0
# sanagasta                  0.0                    0.0                  0.0
# bombolo                    0.0                    0.0                  0.0
# aijue                      0.0                    0.0                  0.0
# mitai                      0.0                    0.0                  0.0
# aij                        0.0                    0.0                  0.0
# fne                        0.0                    0.0                  0.0
# unse                       0.0                    0.0                  0.0
# quintela                   0.0                    0.0                  0.0
# fsa                        0.0                    0.0                  0.0
# olta                       0.0                    0.0                  0.0
# larioja                    0.0                    0.0                  0.0
# calahorra                  0.0                    0.0                  0.0
# edese                      0.0                    0.0                  0.0
# veril                      0.0                   91.0                  0.0
# yarca                      0.0                    0.0                  0.0
# breñas                     0.0                    0.0                  0.0
# nájera                     0.0                    0.0                  0.0
# tineo                      0.0                    0.0                  0.0
# mitacuñai                  0.0                    0.0                  0.0
# cincue                     0.0                    0.0                  0.0
# corvina                    0.0                    0.0                  0.0
# chivil                     0.0                    0.0                  0.0
# derasore                   0.0                    0.0                  0.0
# bombolos                   0.0                    0.0                  0.0
# formosaa                   0.0                    0.0                  0.0
# chijra                     0.0                    0.0                  0.0
# poec                       0.0                    0.0                  0.0
# ulapes                     0.0                    0.0                  0.0
#
#            santiago_ocurrencias  tierradelfuego_ocurrencias  \
# bombola                     0.0                         0.0
# logroño                     0.0                         0.0
# sanagasta                   0.0                         0.0
# bombolo                     0.0                         0.0
# aijue                       0.0                         0.0
# mitai                       0.0                         0.0
# aij                         0.0                         0.0
# fne                         0.0                         0.0
# unse                       50.0                         0.0
# quintela                    0.0                         0.0
# fsa                         0.0                         8.0
# olta                        0.0                         0.0
# larioja                     0.0                         0.0
# calahorra                   0.0                         0.0
# edese                      38.0                         0.0
# veril                       0.0                         0.0
# yarca                       0.0                         0.0
# breñas                      0.0                         0.0
# nájera                      0.0                         0.0
# tineo                       0.0                         0.0
# mitacuñai                   0.0                         0.0
# cincue                      0.0                         0.0
# corvina                     0.0                         0.0
# chivil                      0.0                         0.0
# derasore                    0.0                         0.0
# bombolos                    0.0                         0.0
# formosaa                    0.0                         0.0
# chijra                      0.0                         0.0
# poec                        0.0                         0.0
# ulapes                      0.0                         0.0
#
#            tucuman_ocurrencias
# bombola                    0.0
# logroño                    0.0
# sanagasta                  0.0
# bombolo                    0.0
# aijue                      0.0
# mitai                      0.0
# aij                        0.0
# fne                        0.0
# unse                       0.0
# quintela                   0.0
# fsa                        0.0
# olta                       0.0
# larioja                    0.0
# calahorra                  0.0
# edese                      0.0
# veril                      0.0
# yarca                      0.0
# breñas                     0.0
# nájera                     0.0
# tineo                      0.0
# mitacuñai                  0.0
# cincue                     0.0
# corvina                    0.0
# chivil                     0.0
# derasore                   0.0
# bombolos                   0.0
# formosaa                   0.0
# chijra                     0.0
# poec                       0.0
# ulapes                     0.0
#
# [30 rows x 23 columns]

# %% [markdown]
# Veamos qué performance tiene usando 1000, 2000, 3000, y así...

# %%
print("Tenemos {} palabras".format(len(word_df)))
# Out:
# Tenemos 103782 palabras

# %%
# %%time
from sklearn.feature_extraction.text import CountVectorizer
from contrastes.text import tokenize

liw_vectorizer = CountVectorizer(
    tokenizer=tokenize,
    vocabulary=word_df.index)

X_train = liw_vectorizer.fit_transform(df_train["text"])
print("Vectorizing")
X_test = liw_vectorizer.transform(df_test["text"])
# Out:
# Vectorizing
# CPU times: user 10min 16s, sys: 1.26 s, total: 10min 17s
# Wall time: 10min 17s

# %% [markdown]
# Ya las tenemos vectorizadas en el orden esperado!

# %%
from sklearn.preprocessing import LabelEncoder

province_encoder = LabelEncoder()

province_encoder.fit(df_train["provincia"].values)

y_train = province_encoder.transform(df_train["provincia"].values)
y_test = province_encoder.transform(df_test["provincia"].values)

# %%
# %%time
from contrastes.classifiers import fit_classifiers

num_words_to_fit = list(range(250, 5000, 250)) + list(range(5000, 20000, 500))

params = {"max_iter": 7000}

ret = fit_classifiers(X_train, y_train, X_test, y_test, 
                      province_encoder=province_encoder, clf_params=params,
                      range_num_words=num_words_to_fit, num_jobs=12)
# Out:
# Classifier params: {'multi_class': 'multinomial', 'solver': 'saga', 'penalty': 'l2', 'max_iter': 7000}
# Entrenando con 750 palabras
# Entrenando con 250 palabras
# Entrenando con 2250 palabras
# Entrenando con 1250 palabras
# Entrenando con 1750 palabras
# Entrenando con 3750 palabras
# Entrenando con 3250 palabras
# Entrenando con 2750 palabras
# Entrenando con 4250 palabras
# Entrenando con 5500 palabras
# Entrenando con 4750 palabras
# Entrenando con 6500 palabras
# 250   palabras ----> accuracy 36.16 mean distance 632.0648
# Entrenando con 500 palabras
# 750   palabras ----> accuracy 50.80 mean distance 492.4676
# Entrenando con 1000 palabras
# 1250  palabras ----> accuracy 60.16 mean distance 393.7628
# Entrenando con 1500 palabras
# 1750  palabras ----> accuracy 64.16 mean distance 356.9404
# Entrenando con 2000 palabras
# 2250  palabras ----> accuracy 69.24 mean distance 314.4144
# Entrenando con 2500 palabras
# 2750  palabras ----> accuracy 70.32 mean distance 234.2132
# Entrenando con 3000 palabras
# 3250  palabras ----> accuracy 71.96 mean distance 224.1312
# Entrenando con 3500 palabras
# 4250  palabras ----> accuracy 73.72 mean distance 249.6748
# Entrenando con 4500 palabras
# 3750  palabras ----> accuracy 73.04 mean distance 257.0116
# Entrenando con 4000 palabras
# 4750  palabras ----> accuracy 74.36 mean distance 237.7744
# Entrenando con 5000 palabras
# 5500  palabras ----> accuracy 74.88 mean distance 229.0776
# Entrenando con 6000 palabras
# 500   palabras ----> accuracy 44.60 mean distance 542.0792
# Entrenando con 7500 palabras
# 6500  palabras ----> accuracy 75.72 mean distance 218.1856
# Entrenando con 7000 palabras
# 1000  palabras ----> accuracy 55.64 mean distance 436.9324
# Entrenando con 8500 palabras
# 1500  palabras ----> accuracy 62.32 mean distance 376.7876
# Entrenando con 9500 palabras
# 2000  palabras ----> accuracy 67.40 mean distance 316.8856
# Entrenando con 10500 palabras
# 3000  palabras ----> accuracy 71.64 mean distance 225.6068
# Entrenando con 11500 palabras
# 2500  palabras ----> accuracy 70.28 mean distance 236.2344
# Entrenando con 12500 palabras
# 3500  palabras ----> accuracy 72.28 mean distance 220.1132
# Entrenando con 13500 palabras
# 4000  palabras ----> accuracy 73.36 mean distance 250.6696
# Entrenando con 14500 palabras
# 4500  palabras ----> accuracy 73.96 mean distance 242.1176
# Entrenando con 15500 palabras
# 5000  palabras ----> accuracy 74.88 mean distance 234.7164
# Entrenando con 16500 palabras
# 6000  palabras ----> accuracy 75.12 mean distance 224.916
# Entrenando con 17500 palabras
# 7500  palabras ----> accuracy 76.44 mean distance 208.0104
# Entrenando con 8000 palabras
# 7000  palabras ----> accuracy 76.20 mean distance 211.696
# Entrenando con 18500 palabras
# 8500  palabras ----> accuracy 77.00 mean distance 195.8488
# Entrenando con 9000 palabras
# 9500  palabras ----> accuracy 77.60 mean distance 191.6756
# Entrenando con 10000 palabras
# 10500 palabras ----> accuracy 76.32 mean distance 185.9932
# Entrenando con 11000 palabras
# 11500 palabras ----> accuracy 76.40 mean distance 185.8812
# Entrenando con 12000 palabras
# 12500 palabras ----> accuracy 76.60 mean distance 184.9608
# Entrenando con 13000 palabras
# 8000  palabras ----> accuracy 76.20 mean distance 209.746
# Entrenando con 19500 palabras
# 13500 palabras ----> accuracy 76.88 mean distance 183.88
# Entrenando con 14000 palabras
# 9000  palabras ----> accuracy 77.36 mean distance 195.3664
# 14500 palabras ----> accuracy 76.52 mean distance 186.1712
# Entrenando con 15000 palabras
# 10000 palabras ----> accuracy 77.92 mean distance 187.2236
# 15500 palabras ----> accuracy 76.48 mean distance 185.6748
# Entrenando con 16000 palabras
# 16500 palabras ----> accuracy 76.44 mean distance 186.0424
# Entrenando con 17000 palabras
# 17500 palabras ----> accuracy 75.28 mean distance 197.8152
# Entrenando con 18000 palabras
# 11000 palabras ----> accuracy 76.40 mean distance 185.8268
# 12000 palabras ----> accuracy 76.68 mean distance 183.7584
# 18500 palabras ----> accuracy 75.36 mean distance 196.8016
# Entrenando con 19000 palabras
# 13000 palabras ----> accuracy 76.84 mean distance 185.314
# 14000 palabras ----> accuracy 77.00 mean distance 183.0704
# 15000 palabras ----> accuracy 76.48 mean distance 186.6988
# 19500 palabras ----> accuracy 75.48 mean distance 196.8588
# 16000 palabras ----> accuracy 76.60 mean distance 184.9476
# 17000 palabras ----> accuracy 76.00 mean distance 190.268
# 18000 palabras ----> accuracy 75.44 mean distance 196.3188
# 19000 palabras ----> accuracy 75.52 mean distance 195.2432
# CPU times: user 1.07 s, sys: 1.3 s, total: 2.37 s
# Wall time: 15min 14s

# %%
for r in ret:
    num_words = r["num_words"]
    acc = r["accuracy"]
    md = r["mean_distance"]
    print("{:<5} palabras ----> accuracy {:.2f} mean distance {}".format(
        num_words, acc*100, md
    ))
# Out:
# 250   palabras ----> accuracy 36.16 mean distance 632.0648
# 500   palabras ----> accuracy 44.60 mean distance 542.0792
# 750   palabras ----> accuracy 50.80 mean distance 492.4676
# 1000  palabras ----> accuracy 55.64 mean distance 436.9324
# 1250  palabras ----> accuracy 60.16 mean distance 393.7628
# 1500  palabras ----> accuracy 62.32 mean distance 376.7876
# 1750  palabras ----> accuracy 64.16 mean distance 356.9404
# 2000  palabras ----> accuracy 67.40 mean distance 316.8856
# 2250  palabras ----> accuracy 69.24 mean distance 314.4144
# 2500  palabras ----> accuracy 70.28 mean distance 236.2344
# 2750  palabras ----> accuracy 70.32 mean distance 234.2132
# 3000  palabras ----> accuracy 71.64 mean distance 225.6068
# 3250  palabras ----> accuracy 71.96 mean distance 224.1312
# 3500  palabras ----> accuracy 72.28 mean distance 220.1132
# 3750  palabras ----> accuracy 73.04 mean distance 257.0116
# 4000  palabras ----> accuracy 73.36 mean distance 250.6696
# 4250  palabras ----> accuracy 73.72 mean distance 249.6748
# 4500  palabras ----> accuracy 73.96 mean distance 242.1176
# 4750  palabras ----> accuracy 74.36 mean distance 237.7744
# 5000  palabras ----> accuracy 74.88 mean distance 234.7164
# 5500  palabras ----> accuracy 74.88 mean distance 229.0776
# 6000  palabras ----> accuracy 75.12 mean distance 224.916
# 6500  palabras ----> accuracy 75.72 mean distance 218.1856
# 7000  palabras ----> accuracy 76.20 mean distance 211.696
# 7500  palabras ----> accuracy 76.44 mean distance 208.0104
# 8000  palabras ----> accuracy 76.20 mean distance 209.746
# 8500  palabras ----> accuracy 77.00 mean distance 195.8488
# 9000  palabras ----> accuracy 77.36 mean distance 195.3664
# 9500  palabras ----> accuracy 77.60 mean distance 191.6756
# 10000 palabras ----> accuracy 77.92 mean distance 187.2236
# 10500 palabras ----> accuracy 76.32 mean distance 185.9932
# 11000 palabras ----> accuracy 76.40 mean distance 185.8268
# 11500 palabras ----> accuracy 76.40 mean distance 185.8812
# 12000 palabras ----> accuracy 76.68 mean distance 183.7584
# 12500 palabras ----> accuracy 76.60 mean distance 184.9608
# 13000 palabras ----> accuracy 76.84 mean distance 185.314
# 13500 palabras ----> accuracy 76.88 mean distance 183.88
# 14000 palabras ----> accuracy 77.00 mean distance 183.0704
# 14500 palabras ----> accuracy 76.52 mean distance 186.1712
# 15000 palabras ----> accuracy 76.48 mean distance 186.6988
# 15500 palabras ----> accuracy 76.48 mean distance 185.6748
# 16000 palabras ----> accuracy 76.60 mean distance 184.9476
# 16500 palabras ----> accuracy 76.44 mean distance 186.0424
# 17000 palabras ----> accuracy 76.00 mean distance 190.268
# 17500 palabras ----> accuracy 75.28 mean distance 197.8152
# 18000 palabras ----> accuracy 75.44 mean distance 196.3188
# 18500 palabras ----> accuracy 75.36 mean distance 196.8016
# 19000 palabras ----> accuracy 75.52 mean distance 195.2432
# 19500 palabras ----> accuracy 75.48 mean distance 196.8588

# %%
import pickle

pickle.dump(ret, open("res_igr_personas.pkl", "wb"))

# %%
new_ret = pickle.load(open("res_igr_personas.pkl", "rb"))

clf = new_ret[-1]["clf"]

clf.coef_.shape
# Out:
# (23, 19500)
