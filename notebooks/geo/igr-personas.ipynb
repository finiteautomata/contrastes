# %% [markdown]
# # Geolocalización con MultiProcessing + IGR Personas
#
# En esta notebook haremos un intento de geolocalización con los textos de los usuarios...

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd

df_train = pd.read_json("../data/geoloc/users_train.json")
df_test = pd.read_json("../data/geoloc/users_test.json")

# %% [markdown]
# Hagamos lo siguiente:
#
# - Entrenemos con unigramas una regresión logística para
# - Luego probemos con los regionalismos
#
# Primero, partamos en train, test

# %%
df_train.groupby("provincia").count()
# Out:
#                 text
# provincia
# buenosaires      337
# catamarca        341
# chaco            331
# chubut           328
# cordoba          317
# corrientes       345
# entrerios        338
# formosa          286
# jujuy            339
# lapampa          324
# larioja          306
# mendoza          326
# misiones         327
# neuquen          350
# rionegro         313
# salta            346
# sanjuan          326
# sanluis          321
# santacruz        288
# santafe          347
# santiago         294
# tierradelfuego   332
# tucuman          338

# %% [markdown]
# ## Palabras precalculadas
#
# Carguemos antes las palabras que sabemos que ocurren una cantidad razonable de veces

# %%
# %%time
from contrastes.processing import build_dataframe_from_users
from contrastes.processing import preprocess_raw_df


#word_df = build_dataframe_from_users(row for index, row in df_train.iterrows())

word_df = pd.read_csv("train_word_df_filtered.csv", index_col=0)
word_df = preprocess_raw_df(word_df, filter_words=(10, 2))
# Out:
# CPU times: user 1.47 s, sys: 224 ms, total: 1.7 s
# Wall time: 1.69 s
# /home/jmperez/projects/contrastes/contrastes/processing.py:185: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnas_palabras = cant_palabras
# /home/jmperez/projects/contrastes/contrastes/processing.py:186: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnas_personas = cant_personas

# %% [markdown]
# La reg. logística será un softmax, así que elijo `multi_class='multinomial'`

# %%
from contrastes.igr import igr

word_df["igr"] = igr(word_df, word_df.columnas_personas)

# %%
word_df.sort_values("igr", ascending=False, inplace=True)

word_df[:30][word_df.columnas_palabras]
# Out:
#            buenosaires_ocurrencias  catamarca_ocurrencias  chaco_ocurrencias  \
# bombola                        0.0                    0.0                0.0
# logroño                        0.0                    0.0                0.0
# sanagasta                      0.0                    0.0                0.0
# bombolo                        0.0                    0.0                4.0
# aijue                          0.0                    0.0                0.0
# mitai                          0.0                    0.0                0.0
# aij                            0.0                    0.0                0.0
# fne                            0.0                    0.0                0.0
# unse                           0.0                    0.0                0.0
# quintela                       0.0                    0.0                0.0
# fsa                            0.0                    0.0               22.0
# olta                           0.0                    0.0                0.0
# larioja                        0.0                    0.0                0.0
# calahorra                      0.0                    0.0                0.0
# edese                          0.0                    0.0                0.0
# veril                          0.0                    0.0                0.0
# yarca                          0.0                    0.0                0.0
# breñas                         0.0                    0.0              219.0
# nájera                         0.0                    0.0                0.0
# tineo                          0.0                    0.0                0.0
# mitacuñai                      0.0                    0.0                0.0
# cincue                         0.0                    0.0                0.0
# corvina                        0.0                    0.0                0.0
# chivil                       332.0                    0.0                0.0
# derasore                       0.0                    0.0                0.0
# bombolos                       0.0                    0.0                0.0
# formosaa                       0.0                    0.0                0.0
# chijra                         0.0                    0.0                0.0
# poec                           0.0                    0.0                0.0
# ulapes                         0.0                    0.0                0.0
#
#            chubut_ocurrencias  cordoba_ocurrencias  corrientes_ocurrencias  \
# bombola                   0.0                  0.0                     0.0
# logroño                   0.0                  0.0                     0.0
# sanagasta                 0.0                  0.0                     0.0
# bombolo                   0.0                  0.0                     0.0
# aijue                     0.0                  0.0                     2.0
# mitai                     0.0                  0.0                     7.0
# aij                       0.0                  0.0                     0.0
# fne                       0.0                  0.0                     0.0
# unse                      0.0                  0.0                     0.0
# quintela                  0.0                  0.0                     0.0
# fsa                       0.0                  4.0                     4.0
# olta                      0.0                  0.0                     0.0
# larioja                   0.0                  0.0                     0.0
# calahorra                 0.0                  0.0                     0.0
# edese                     0.0                  0.0                     0.0
# veril                     0.0                  0.0                     0.0
# yarca                     0.0                  0.0                     0.0
# breñas                    0.0                  0.0                     7.0
# nájera                    0.0                  0.0                     0.0
# tineo                     0.0                  0.0                     0.0
# mitacuñai                 0.0                  0.0                     0.0
# cincue                    0.0                  0.0                     0.0
# corvina                   0.0                  0.0                     0.0
# chivil                    0.0                  0.0                     0.0
# derasore                  0.0                  0.0                     0.0
# bombolos                  0.0                  0.0                     0.0
# formosaa                  0.0                  0.0                     0.0
# chijra                    0.0                  0.0                     0.0
# poec                      0.0                  0.0                     0.0
# ulapes                    0.0                  0.0                     0.0
#
#            entrerios_ocurrencias  formosa_ocurrencias  jujuy_ocurrencias  \
# bombola                      0.0                 75.0                0.0
# logroño                      0.0                  0.0                0.0
# sanagasta                    0.0                  0.0                1.0
# bombolo                      0.0                 69.0                0.0
# aijue                        1.0                237.0                0.0
# mitai                        0.0                123.0                0.0
# aij                          0.0                 30.0                0.0
# fne                          0.0                  0.0               75.0
# unse                         0.0                  0.0                0.0
# quintela                     0.0                  0.0                0.0
# fsa                          0.0                282.0                0.0
# olta                         0.0                  0.0                0.0
# larioja                      0.0                  0.0                0.0
# calahorra                    0.0                  0.0                0.0
# edese                        0.0                  0.0                0.0
# veril                        0.0                  0.0                0.0
# yarca                        0.0                  0.0                0.0
# breñas                       0.0                  0.0                0.0
# nájera                       0.0                  0.0                0.0
# tineo                        0.0                  0.0                0.0
# mitacuñai                    0.0                 14.0                0.0
# cincue                       0.0                 43.0                0.0
# corvina                      0.0                 54.0                0.0
# chivil                       0.0                  0.0                0.0
# derasore                     0.0                 17.0                0.0
# bombolos                     0.0                 13.0                0.0
# formosaa                     0.0                 13.0                0.0
# chijra                       0.0                  0.0               31.0
# poec                         0.0                  0.0                0.0
# ulapes                       0.0                  0.0                0.0
#
#            lapampa_ocurrencias         ...           neuquen_ocurrencias  \
# bombola                    0.0         ...                           0.0
# logroño                    0.0         ...                           0.0
# sanagasta                  1.0         ...                           0.0
# bombolo                    0.0         ...                           0.0
# aijue                      0.0         ...                           0.0
# mitai                      0.0         ...                           0.0
# aij                        0.0         ...                           0.0
# fne                        0.0         ...                           0.0
# unse                       0.0         ...                           0.0
# quintela                   0.0         ...                           0.0
# fsa                        0.0         ...                           0.0
# olta                       0.0         ...                           0.0
# larioja                    0.0         ...                           0.0
# calahorra                  0.0         ...                           0.0
# edese                      0.0         ...                           0.0
# veril                      0.0         ...                           0.0
# yarca                      0.0         ...                           0.0
# breñas                     0.0         ...                           0.0
# nájera                     0.0         ...                           0.0
# tineo                      0.0         ...                           0.0
# mitacuñai                  0.0         ...                           0.0
# cincue                     0.0         ...                           0.0
# corvina                    1.0         ...                           0.0
# chivil                     0.0         ...                           0.0
# derasore                   0.0         ...                           0.0
# bombolos                   0.0         ...                           0.0
# formosaa                   0.0         ...                           0.0
# chijra                     0.0         ...                           0.0
# poec                       0.0         ...                         163.0
# ulapes                     0.0         ...                           0.0
#
#            rionegro_ocurrencias  salta_ocurrencias  sanjuan_ocurrencias  \
# bombola                     0.0                0.0                  0.0
# logroño                     0.0                0.0                  0.0
# sanagasta                   0.0                0.0                  0.0
# bombolo                     0.0                0.0                  0.0
# aijue                       0.0                0.0                  0.0
# mitai                       0.0                0.0                  0.0
# aij                         0.0                0.0                  0.0
# fne                         0.0                1.0                  0.0
# unse                        0.0                0.0                  0.0
# quintela                    0.0                0.0                  0.0
# fsa                         0.0                0.0                  0.0
# olta                        0.0                0.0                  0.0
# larioja                     0.0                0.0                  0.0
# calahorra                   0.0                0.0                  0.0
# edese                       0.0                0.0                  0.0
# veril                       0.0                0.0                  0.0
# yarca                       0.0                0.0                160.0
# breñas                      0.0                0.0                  0.0
# nájera                      0.0                0.0                  0.0
# tineo                       0.0                0.0                  0.0
# mitacuñai                   0.0                0.0                  0.0
# cincue                      0.0                0.0                  0.0
# corvina                     1.0                0.0                  0.0
# chivil                      0.0                0.0                  0.0
# derasore                    0.0                0.0                  0.0
# bombolos                    0.0                0.0                  0.0
# formosaa                    0.0                0.0                  0.0
# chijra                      0.0                0.0                  0.0
# poec                        0.0                0.0                  0.0
# ulapes                      0.0                0.0                  0.0
#
#            sanluis_ocurrencias  santacruz_ocurrencias  santafe_ocurrencias  \
# bombola                    0.0                    0.0                  0.0
# logroño                    0.0                    0.0                  0.0
# sanagasta                  0.0                    0.0                  0.0
# bombolo                    0.0                    0.0                  0.0
# aijue                      0.0                    0.0                  0.0
# mitai                      0.0                    0.0                  0.0
# aij                        0.0                    0.0                  0.0
# fne                        0.0                    0.0                  0.0
# unse                       0.0                    0.0                  0.0
# quintela                   0.0                    0.0                  0.0
# fsa                        0.0                    0.0                  0.0
# olta                       0.0                    0.0                  0.0
# larioja                    0.0                    0.0                  0.0
# calahorra                  0.0                    0.0                  0.0
# edese                      0.0                    0.0                  0.0
# veril                      0.0                   91.0                  0.0
# yarca                      0.0                    0.0                  0.0
# breñas                     0.0                    0.0                  0.0
# nájera                     0.0                    0.0                  0.0
# tineo                      0.0                    0.0                  0.0
# mitacuñai                  0.0                    0.0                  0.0
# cincue                     0.0                    0.0                  0.0
# corvina                    0.0                    0.0                  0.0
# chivil                     0.0                    0.0                  0.0
# derasore                   0.0                    0.0                  0.0
# bombolos                   0.0                    0.0                  0.0
# formosaa                   0.0                    0.0                  0.0
# chijra                     0.0                    0.0                  0.0
# poec                       0.0                    0.0                  0.0
# ulapes                     0.0                    0.0                  0.0
#
#            santiago_ocurrencias  tierradelfuego_ocurrencias  \
# bombola                     0.0                         0.0
# logroño                     0.0                         0.0
# sanagasta                   0.0                         0.0
# bombolo                     0.0                         0.0
# aijue                       0.0                         0.0
# mitai                       0.0                         0.0
# aij                         0.0                         0.0
# fne                         0.0                         0.0
# unse                       50.0                         0.0
# quintela                    0.0                         0.0
# fsa                         0.0                         8.0
# olta                        0.0                         0.0
# larioja                     0.0                         0.0
# calahorra                   0.0                         0.0
# edese                      38.0                         0.0
# veril                       0.0                         0.0
# yarca                       0.0                         0.0
# breñas                      0.0                         0.0
# nájera                      0.0                         0.0
# tineo                       0.0                         0.0
# mitacuñai                   0.0                         0.0
# cincue                      0.0                         0.0
# corvina                     0.0                         0.0
# chivil                      0.0                         0.0
# derasore                    0.0                         0.0
# bombolos                    0.0                         0.0
# formosaa                    0.0                         0.0
# chijra                      0.0                         0.0
# poec                        0.0                         0.0
# ulapes                      0.0                         0.0
#
#            tucuman_ocurrencias
# bombola                    0.0
# logroño                    0.0
# sanagasta                  0.0
# bombolo                    0.0
# aijue                      0.0
# mitai                      0.0
# aij                        0.0
# fne                        0.0
# unse                       0.0
# quintela                   0.0
# fsa                        0.0
# olta                       0.0
# larioja                    0.0
# calahorra                  0.0
# edese                      0.0
# veril                      0.0
# yarca                      0.0
# breñas                     0.0
# nájera                     0.0
# tineo                      0.0
# mitacuñai                  0.0
# cincue                     0.0
# corvina                    0.0
# chivil                     0.0
# derasore                   0.0
# bombolos                   0.0
# formosaa                   0.0
# chijra                     0.0
# poec                       0.0
# ulapes                     0.0
#
# [30 rows x 23 columns]

# %% [markdown]
# Veamos qué performance tiene usando 1000, 2000, 3000, y así...

# %%
# %%time
from sklearn.feature_extraction.text import CountVectorizer
from contrastes.text import tokenize

liw_vectorizer = CountVectorizer(
    tokenizer=tokenize,
    vocabulary=word_df.index)

X_train = liw_vectorizer.fit_transform(df_train["text"])
print("Vectorizing")
X_test = liw_vectorizer.transform(df_test["text"])
# Out:
# Vectorizing
# CPU times: user 10min 22s, sys: 1.16 s, total: 10min 23s
# Wall time: 10min 23s

# %% [markdown]
# Ya las tenemos vectorizadas en el orden esperado!

# %%
from sklearn.preprocessing import LabelEncoder

province_encoder = LabelEncoder()

province_encoder.fit(df_train["provincia"].values)

y_train = province_encoder.transform(df_train["provincia"].values)
y_test = province_encoder.transform(df_test["provincia"].values)

# %%
# %%time
from contrastes.classifiers import fit_classifiers

num_words_to_fit = list(range(250, 5000, 250)) + list(range(5000, 20000, 500))

ret = fit_classifiers(X_train, y_train, X_test, y_test, 
                      province_encoder=province_encoder,
                      range_num_words=num_words_to_fit, num_jobs=8)
# Out:
# Entrenando con 250 palabras
# Entrenando con 750 palabras
# Entrenando con 1250 palabras
# Entrenando con 1750 palabras
# Entrenando con 2250 palabras
# Entrenando con 2750 palabras
# Entrenando con 3250 palabras
# Entrenando con 3750 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 250   palabras ----> accuracy 35.32 mean distance 512.7888
# Entrenando con 500 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 750   palabras ----> accuracy 49.44 mean distance 406.2552
# Entrenando con 1000 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 1250  palabras ----> accuracy 58.72 mean distance 338.7972
# Entrenando con 1500 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 1750  palabras ----> accuracy 63.04 mean distance 361.7928
# Entrenando con 2000 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 2250  palabras ----> accuracy 68.00 mean distance 321.3048
# Entrenando con 2500 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 2750  palabras ----> accuracy 68.64 mean distance 300.944
# Entrenando con 3000 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 3250  palabras ----> accuracy 69.88 mean distance 283.8432
# Entrenando con 3500 palabras
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 3750  palabras ----> accuracy 70.48 mean distance 274.104
# Entrenando con 4000 palabras
# 500   palabras ----> accuracy 43.32 mean distance 448.2648
# Entrenando con 4250 palabras
# 1000  palabras ----> accuracy 54.40 mean distance 367.8736
# Entrenando con 4750 palabras
# 1500  palabras ----> accuracy 61.88 mean distance 380.0864
# Entrenando con 5500 palabras
# 2000  palabras ----> accuracy 65.96 mean distance 323.2856
# Entrenando con 6500 palabras
# 2500  palabras ----> accuracy 68.84 mean distance 305.3228
# Entrenando con 7500 palabras
# 3000  palabras ----> accuracy 69.40 mean distance 289.4456
# Entrenando con 8500 palabras
# 3500  palabras ----> accuracy 70.24 mean distance 277.3524
# Entrenando con 9500 palabras
# 4000  palabras ----> accuracy 70.36 mean distance 270.686
# Entrenando con 10500 palabras
# 4250  palabras ----> accuracy 70.60 mean distance 266.756
# Entrenando con 4500 palabras
# 4750  palabras ----> accuracy 71.76 mean distance 256.4124
# Entrenando con 5000 palabras
# 5500  palabras ----> accuracy 72.40 mean distance 247.8792
# Entrenando con 6000 palabras
# 6500  palabras ----> accuracy 73.08 mean distance 217.4876
# Entrenando con 7000 palabras
# 7500  palabras ----> accuracy 73.68 mean distance 214.0772
# Entrenando con 8000 palabras
# 4500  palabras ----> accuracy 71.60 mean distance 259.0224
# Entrenando con 11500 palabras
# 8500  palabras ----> accuracy 74.76 mean distance 199.4044
# Entrenando con 9000 palabras
# 9500  palabras ----> accuracy 74.32 mean distance 201.1816
# Entrenando con 10000 palabras
# 5000  palabras ----> accuracy 72.36 mean distance 251.9024
# Entrenando con 12500 palabras
# 10500 palabras ----> accuracy 72.80 mean distance 211.0676
# Entrenando con 11000 palabras
# 6000  palabras ----> accuracy 72.56 mean distance 223.1136
# Entrenando con 13500 palabras
# 7000  palabras ----> accuracy 73.32 mean distance 215.7188
# Entrenando con 14500 palabras
# 8000  palabras ----> accuracy 73.68 mean distance 215.8112
# Entrenando con 15500 palabras
# 9000  palabras ----> accuracy 74.76 mean distance 199.8
# Entrenando con 16500 palabras
# 11500 palabras ----> accuracy 73.00 mean distance 209.2624
# Entrenando con 12000 palabras
# 10000 palabras ----> accuracy 74.48 mean distance 199.8748
# Entrenando con 17500 palabras
# 11000 palabras ----> accuracy 73.04 mean distance 208.1808
# Entrenando con 18500 palabras
# 12500 palabras ----> accuracy 73.20 mean distance 212.1256
# Entrenando con 13000 palabras
# 13500 palabras ----> accuracy 73.24 mean distance 213.0416
# Entrenando con 14000 palabras
# 14500 palabras ----> accuracy 72.96 mean distance 214.0792
# Entrenando con 15000 palabras
# 15500 palabras ----> accuracy 72.76 mean distance 215.942
# Entrenando con 16000 palabras
# 12000 palabras ----> accuracy 73.12 mean distance 210.5748
# Entrenando con 19500 palabras
# 16500 palabras ----> accuracy 72.76 mean distance 215.35
# Entrenando con 17000 palabras
# 13000 palabras ----> accuracy 73.20 mean distance 214.9784
# 17500 palabras ----> accuracy 70.56 mean distance 231.7332
# Entrenando con 18000 palabras
# 14000 palabras ----> accuracy 73.36 mean distance 212.4496
# 18500 palabras ----> accuracy 70.72 mean distance 230.1468
# Entrenando con 19000 palabras
# 15000 palabras ----> accuracy 72.80 mean distance 216.3096
# 16000 palabras ----> accuracy 72.80 mean distance 214.746
# 17000 palabras ----> accuracy 71.72 mean distance 218.698
# 19500 palabras ----> accuracy 70.96 mean distance 229.6796
# 18000 palabras ----> accuracy 70.76 mean distance 229.8376
# 19000 palabras ----> accuracy 70.88 mean distance 228.9056
# CPU times: user 204 ms, sys: 676 ms, total: 880 ms
# Wall time: 1min 4s

# %%
for r in ret:
    num_words = r["num_words"]
    acc = r["accuracy"]
    md = r["mean_distance"]
    print("{:<5} palabras ----> accuracy {:.2f} mean distance {}".format(
        num_words, acc*100, md
    ))
# Out:
# 250   palabras ----> accuracy 35.32 mean distance 512.7888
# 500   palabras ----> accuracy 43.32 mean distance 448.2648
# 750   palabras ----> accuracy 49.44 mean distance 406.2552
# 1000  palabras ----> accuracy 54.40 mean distance 367.8736
# 1250  palabras ----> accuracy 58.72 mean distance 338.7972
# 1500  palabras ----> accuracy 61.88 mean distance 380.0864
# 1750  palabras ----> accuracy 63.04 mean distance 361.7928
# 2000  palabras ----> accuracy 65.96 mean distance 323.2856
# 2250  palabras ----> accuracy 68.00 mean distance 321.3048
# 2500  palabras ----> accuracy 68.84 mean distance 305.3228
# 2750  palabras ----> accuracy 68.64 mean distance 300.944
# 3000  palabras ----> accuracy 69.40 mean distance 289.4456
# 3250  palabras ----> accuracy 69.88 mean distance 283.8432
# 3500  palabras ----> accuracy 70.24 mean distance 277.3524
# 3750  palabras ----> accuracy 70.48 mean distance 274.104
# 4000  palabras ----> accuracy 70.36 mean distance 270.686
# 4250  palabras ----> accuracy 70.60 mean distance 266.756
# 4500  palabras ----> accuracy 71.60 mean distance 259.0224
# 4750  palabras ----> accuracy 71.76 mean distance 256.4124
# 5000  palabras ----> accuracy 72.36 mean distance 251.9024
# 5500  palabras ----> accuracy 72.40 mean distance 247.8792
# 6000  palabras ----> accuracy 72.56 mean distance 223.1136
# 6500  palabras ----> accuracy 73.08 mean distance 217.4876
# 7000  palabras ----> accuracy 73.32 mean distance 215.7188
# 7500  palabras ----> accuracy 73.68 mean distance 214.0772
# 8000  palabras ----> accuracy 73.68 mean distance 215.8112
# 8500  palabras ----> accuracy 74.76 mean distance 199.4044
# 9000  palabras ----> accuracy 74.76 mean distance 199.8
# 9500  palabras ----> accuracy 74.32 mean distance 201.1816
# 10000 palabras ----> accuracy 74.48 mean distance 199.8748
# 10500 palabras ----> accuracy 72.80 mean distance 211.0676
# 11000 palabras ----> accuracy 73.04 mean distance 208.1808
# 11500 palabras ----> accuracy 73.00 mean distance 209.2624
# 12000 palabras ----> accuracy 73.12 mean distance 210.5748
# 12500 palabras ----> accuracy 73.20 mean distance 212.1256
# 13000 palabras ----> accuracy 73.20 mean distance 214.9784
# 13500 palabras ----> accuracy 73.24 mean distance 213.0416
# 14000 palabras ----> accuracy 73.36 mean distance 212.4496
# 14500 palabras ----> accuracy 72.96 mean distance 214.0792
# 15000 palabras ----> accuracy 72.80 mean distance 216.3096
# 15500 palabras ----> accuracy 72.76 mean distance 215.942
# 16000 palabras ----> accuracy 72.80 mean distance 214.746
# 16500 palabras ----> accuracy 72.76 mean distance 215.35
# 17000 palabras ----> accuracy 71.72 mean distance 218.698
# 17500 palabras ----> accuracy 70.56 mean distance 231.7332
# 18000 palabras ----> accuracy 70.76 mean distance 229.8376
# 18500 palabras ----> accuracy 70.72 mean distance 230.1468
# 19000 palabras ----> accuracy 70.88 mean distance 228.9056
# 19500 palabras ----> accuracy 70.96 mean distance 229.6796

# %%
import pickle

pickle.dump(ret, open("res_igr_personas.pkl", "wb"))

# %%
new_ret = pickle.load(open("res_igr_personas.pkl", "rb"))

clf = new_ret[-1]["clf"]

clf.coef_.shape
# Out:
# (23, 19500)
