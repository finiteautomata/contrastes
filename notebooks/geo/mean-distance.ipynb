# %% [markdown]
# # Geolocalización mean distance
#
# Calculemos, en vez de accuracy, las métricas de mean y median distance
#
# [Geolocation prediction in social media data by finding location indicative words](http://www.aclweb.org/anthology/C12-1064)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd

dist_df = pd.read_csv("../data/geoloc/distancias.csv", index_col=0)

def prov_dist(p1, p2):
    return dist_df[p1][p2]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_train = pd.read_json("data/geoloc/users_train.json")
df_test = pd.read_json("data/geoloc/users_test.json")

# %% [markdown]
# Hagamos lo siguiente:
#
# - Entrenemos con unigramas una regresión logística para
# - Luego probemos con los regionalismos
#
# Primero, partamos en train, test

# %% [markdown]
# ## Palabras precalculadas
#
# Carguemos antes las palabras que sabemos que ocurren una cantidad razonable de veces

# %%
# %%time
from contrastes.processing import build_dataframe_from_users

word_df = build_dataframe_from_users(row for index, row in df_train.iterrows())
# Out:
# CPU times: user 8min 33s, sys: 712 ms, total: 8min 34s
# Wall time: 8min 34s

# %%
from contrastes.processing import preprocess_raw_df

word_df = preprocess_raw_df(word_df, filter_words=(10, 2))
# Out:
# /home/jmperez/projects/contrastes/notebooks/contrastes/processing.py:185: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnas_palabras = cant_palabras
# /home/jmperez/projects/contrastes/notebooks/contrastes/processing.py:186: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnas_personas = cant_personas

# %%
from contrastes.lists import add_ival

add_ival(word_df, normalize=True)
# Out:
# Calculating information values...
# Calculating ranks...

# %%
word_df.sort_values("rank_personas", ascending=True, inplace=True)

# %%
# %%time
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords


tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
liw_vectorizer = CountVectorizer(
    tokenizer=tokenizer.tokenize,
    vocabulary=word_df.index[:10000])

X_train = liw_vectorizer.fit_transform(df_train["text"])
print("Vectorizing")
X_test = liw_vectorizer.transform(df_test["text"])
# Out:
# Vectorizing
# CPU times: user 10min 23s, sys: 68 ms, total: 10min 23s
# Wall time: 10min 23s

# %%
print("Vocabulario del vectorizador: {} palabras".format(len(liw_vectorizer.vocabulary_)))
# Out:
# Vocabulario del vectorizador: 10000 palabras

# %%
from sklearn.preprocessing import LabelEncoder

province_encoder = LabelEncoder()

province_encoder.fit(df_train["provincia"].values)
# Out:
# LabelEncoder()

# %%
y_train = province_encoder.transform(df_train["provincia"].values)
y_test = province_encoder.transform(df_test["provincia"].values)

# %% [markdown]
# La reg. logística será un softmax, así que elijo `multi_class='multinomial'`

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(
    multi_class='multinomial', solver='saga', penalty='l2',
    max_iter=200, n_jobs=-1
)

clf.fit(X_train, y_train)
# Out:
# /home/jmperez/.pyenv/versions/3.6.5/envs/contrastes/lib/python3.6/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=200, multi_class='multinomial',
#           n_jobs=-1, penalty='l2', random_state=None, solver='saga',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# Ahora, calculemos las provincias predecidas

# %%
real_prov = province_encoder.inverse_transform(y_test)
pred_prov = province_encoder.inverse_transform(clf.predict(X_test))

# %%
clf.score(X_test, y_test)
# Out:
# 0.7356

# %%
import numpy as np

distances = np.array([prov_dist(p1, p2) for p1, p2 in zip(real_prov, pred_prov)])

distances.mean(), np.median(distances)
# Out:
# (205.6376, 0.0)

# %%
for idx in np.nonzero(distances)[0]:
    print("Real {:<15} predijo {:<15} (distancia {})".format(
        real_prov[idx], pred_prov[idx], distances[idx])
    )
# Out:
# Real santafe         predijo buenosaires     (distancia 393)
# Real mendoza         predijo catamarca       (distancia 569)
# Real catamarca       predijo larioja         (distancia 149)
# Real sanjuan         predijo santafe         (distancia 740)
# Real chubut          predijo tucuman         (distancia 1827)
# Real tucuman         predijo chaco           (distancia 620)
# Real sanluis         predijo sanjuan         (distancia 284)
# Real neuquen         predijo chaco           (distancia 1529)
# Real corrientes      predijo misiones        (distancia 291)
# Real sanjuan         predijo larioja         (distancia 283)
# Real corrientes      predijo chaco           (distancia 13)
# Real santacruz       predijo tierradelfuego  (distancia 359)
# Real sanjuan         predijo santafe         (distancia 740)
# Real santafe         predijo chaco           (distancia 495)
# Real santafe         predijo formosa         (distancia 654)
# Real salta           predijo corrientes      (distancia 719)
# Real sanjuan         predijo rionegro        (distancia 1141)
# Real lapampa         predijo chaco           (distancia 1132)
# Real cordoba         predijo santafe         (distancia 330)
# Real entrerios       predijo jujuy           (distancia 959)
# Real catamarca       predijo tucuman         (distancia 189)
# Real buenosaires     predijo sanluis         (distancia 749)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real cordoba         predijo chaco           (distancia 669)
# Real buenosaires     predijo lapampa         (distancia 579)
# Real larioja         predijo tucuman         (distancia 330)
# Real santafe         predijo formosa         (distancia 654)
# Real salta           predijo catamarca       (distancia 410)
# Real santafe         predijo jujuy           (distancia 942)
# Real cordoba         predijo rionegro        (distancia 1047)
# Real buenosaires     predijo neuquen         (distancia 989)
# Real santafe         predijo chaco           (distancia 495)
# Real rionegro        predijo chaco           (distancia 1526)
# Real neuquen         predijo entrerios       (distancia 1053)
# Real salta           predijo santafe         (distancia 889)
# Real jujuy           predijo tucuman         (distancia 293)
# Real salta           predijo jujuy           (distancia 67)
# Real santiago        predijo mendoza         (distancia 713)
# Real lapampa         predijo chaco           (distancia 1132)
# Real sanluis         predijo entrerios       (distancia 574)
# Real corrientes      predijo chaco           (distancia 13)
# Real santiago        predijo chaco           (distancia 523)
# Real rionegro        predijo lapampa         (distancia 477)
# Real rionegro        predijo chaco           (distancia 1526)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real santafe         predijo lapampa         (distancia 641)
# Real sanjuan         predijo catamarca       (distancia 430)
# Real santafe         predijo jujuy           (distancia 942)
# Real santiago        predijo santacruz       (distancia 2677)
# Real buenosaires     predijo rionegro        (distancia 799)
# Real rionegro        predijo buenosaires     (distancia 799)
# Real tucuman         predijo misiones        (distancia 924)
# Real santafe         predijo cordoba         (distancia 330)
# Real corrientes      predijo chaco           (distancia 13)
# Real buenosaires     predijo cordoba         (distancia 646)
# Real tierradelfuego  predijo sanjuan         (distancia 2585)
# Real santacruz       predijo sanjuan         (distancia 2231)
# Real buenosaires     predijo sanluis         (distancia 749)
# Real buenosaires     predijo santiago        (distancia 939)
# Real chubut          predijo misiones        (distancia 1951)
# Real salta           predijo misiones        (distancia 992)
# Real mendoza         predijo sanluis         (distancia 235)
# Real corrientes      predijo formosa         (distancia 157)
# Real santafe         predijo sanluis         (distancia 560)
# Real salta           predijo tucuman         (distancia 228)
# Real jujuy           predijo salta           (distancia 67)
# Real salta           predijo jujuy           (distancia 67)
# Real buenosaires     predijo sanluis         (distancia 749)
# Real jujuy           predijo tucuman         (distancia 293)
# Real santafe         predijo corrientes      (distancia 498)
# Real santacruz       predijo misiones        (distancia 2914)
# Real santafe         predijo larioja         (distancia 640)
# Real santafe         predijo entrerios       (distancia 19)
# Real santafe         predijo formosa         (distancia 654)
# Real formosa         predijo misiones        (distancia 263)
# Real buenosaires     predijo sanluis         (distancia 749)
# Real sanluis         predijo catamarca       (distancia 540)
# Real cordoba         predijo mendoza         (distancia 466)
# Real entrerios       predijo corrientes      (distancia 500)
# Real entrerios       predijo salta           (distancia 906)
# Real salta           predijo sanluis         (distancia 950)
# Real rionegro        predijo neuquen         (distancia 479)
# Real jujuy           predijo tucuman         (distancia 293)
# Real santacruz       predijo chubut          (distancia 975)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real tucuman         predijo formosa         (distancia 703)
# Real mendoza         predijo chaco           (distancia 1121)
# Real buenosaires     predijo lapampa         (distancia 579)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real mendoza         predijo rionegro        (distancia 1019)
# Real chaco           predijo formosa         (distancia 161)
# Real santiago        predijo chubut          (distancia 1721)
# Real santacruz       predijo chubut          (distancia 975)
# Real mendoza         predijo neuquen         (distancia 676)
# Real santafe         predijo cordoba         (distancia 330)
# Real salta           predijo santafe         (distancia 889)
# Real rionegro        predijo neuquen         (distancia 479)
# Real santafe         predijo sanluis         (distancia 560)
# Real entrerios       predijo chaco           (distancia 498)
# Real santiago        predijo catamarca       (distancia 166)
# Real santafe         predijo entrerios       (distancia 19)
# Real salta           predijo misiones        (distancia 992)
# Real cordoba         predijo santafe         (distancia 330)
# Real salta           predijo jujuy           (distancia 67)
# Real santacruz       predijo tucuman         (distancia 2773)
# Real formosa         predijo chaco           (distancia 161)
# Real cordoba         predijo lapampa         (distancia 577)
# Real salta           predijo santiago        (distancia 353)
# Real entrerios       predijo chaco           (distancia 498)
# Real santacruz       predijo mendoza         (distancia 2081)
# Real santafe         predijo chaco           (distancia 495)
# Real santiago        predijo larioja         (distancia 311)
# Real salta           predijo santafe         (distancia 889)
# Real larioja         predijo santafe         (distancia 640)
# Real salta           predijo jujuy           (distancia 67)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real cordoba         predijo chubut          (distancia 1321)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real santafe         predijo chaco           (distancia 495)
# Real misiones        predijo corrientes      (distancia 291)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real tucuman         predijo jujuy           (distancia 293)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real jujuy           predijo tucuman         (distancia 293)
# Real lapampa         predijo mendoza         (distancia 586)
# Real santacruz       predijo santafe         (distancia 2325)
# Real salta           predijo tucuman         (distancia 228)
# Real entrerios       predijo santafe         (distancia 19)
# Real santafe         predijo entrerios       (distancia 19)
# Real salta           predijo tucuman         (distancia 228)
# Real rionegro        predijo chaco           (distancia 1526)
# Real buenosaires     predijo mendoza         (distancia 985)
# Real rionegro        predijo chubut          (distancia 327)
# Real buenosaires     predijo rionegro        (distancia 799)
# Real corrientes      predijo chaco           (distancia 13)
# Real tierradelfuego  predijo tucuman         (distancia 3116)
# Real sanluis         predijo sanjuan         (distancia 284)
# Real sanluis         predijo catamarca       (distancia 540)
# Real corrientes      predijo jujuy           (distancia 742)
# Real santacruz       predijo tucuman         (distancia 2773)
# Real larioja         predijo santafe         (distancia 640)
# Real santafe         predijo chaco           (distancia 495)
# Real santafe         predijo formosa         (distancia 654)
# Real santiago        predijo formosa         (distancia 629)
# Real rionegro        predijo sanjuan         (distancia 1141)
# Real entrerios       predijo chaco           (distancia 498)
# Real catamarca       predijo larioja         (distancia 149)
# Real santafe         predijo misiones        (distancia 664)
# Real cordoba         predijo santiago        (distancia 401)
# Real jujuy           predijo tucuman         (distancia 293)
# Real santafe         predijo chaco           (distancia 495)
# Real larioja         predijo tucuman         (distancia 330)
# Real santafe         predijo chaco           (distancia 495)
# Real mendoza         predijo sanluis         (distancia 235)
# Real santiago        predijo tucuman         (distancia 141)
# Real santafe         predijo formosa         (distancia 654)
# Real cordoba         predijo jujuy           (distancia 809)
# Real rionegro        predijo mendoza         (distancia 1019)
# Real buenosaires     predijo rionegro        (distancia 799)
# Real buenosaires     predijo tierradelfuego  (distancia 2373)
# Real cordoba         predijo chubut          (distancia 1321)
# Real mendoza         predijo santafe         (distancia 775)
# Real santafe         predijo chaco           (distancia 495)
# Real santacruz       predijo chubut          (distancia 975)
# Real misiones        predijo formosa         (distancia 263)
# Real santafe         predijo chaco           (distancia 495)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real santacruz       predijo chubut          (distancia 975)
# Real santafe         predijo chaco           (distancia 495)
# Real buenosaires     predijo sanluis         (distancia 749)
# Real buenosaires     predijo sanluis         (distancia 749)
# Real buenosaires     predijo cordoba         (distancia 646)
# Real larioja         predijo santiago        (distancia 311)
# Real santafe         predijo lapampa         (distancia 641)
# Real salta           predijo jujuy           (distancia 67)
# Real santafe         predijo lapampa         (distancia 641)
# Real jujuy           predijo santiago        (distancia 414)
# Real lapampa         predijo formosa         (distancia 1293)
# Real buenosaires     predijo corrientes      (distancia 792)
# Real entrerios       predijo corrientes      (distancia 500)
# Real lapampa         predijo entrerios       (distancia 642)
# Real santacruz       predijo sanjuan         (distancia 2231)
# Real mendoza         predijo neuquen         (distancia 676)
# Real santacruz       predijo tierradelfuego  (distancia 359)
# Real larioja         predijo sanjuan         (distancia 283)
# Real cordoba         predijo catamarca       (distancia 362)
# Real corrientes      predijo chaco           (distancia 13)
# Real jujuy           predijo salta           (distancia 67)
# Real santafe         predijo chaco           (distancia 495)
# Real jujuy           predijo tucuman         (distancia 293)
# Real cordoba         predijo jujuy           (distancia 809)
# Real larioja         predijo santafe         (distancia 640)
# Real sanluis         predijo santiago        (distancia 643)
# Real santiago        predijo santafe         (distancia 547)
# Real santafe         predijo chaco           (distancia 495)
# Real salta           predijo catamarca       (distancia 410)
# Real chubut          predijo chaco           (distancia 1843)
# Real lapampa         predijo chaco           (distancia 1132)
# Real tierradelfuego  predijo jujuy           (distancia 3408)
# Real salta           predijo rionegro        (distancia 1790)
# Real salta           predijo catamarca       (distancia 410)
# Real chubut          predijo entrerios       (distancia 1345)
# Real salta           predijo chaco           (distancia 706)
# Real chaco           predijo formosa         (distancia 161)
# Real santafe         predijo chaco           (distancia 495)
# Real rionegro        predijo chubut          (distancia 327)
# Real sanjuan         predijo misiones        (distancia 1306)
# Real rionegro        predijo lapampa         (distancia 477)
# Real catamarca       predijo larioja         (distancia 149)
# Real chubut          predijo cordoba         (distancia 1321)
# Real jujuy           predijo tucuman         (distancia 293)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real salta           predijo tucuman         (distancia 228)
# Real lapampa         predijo chaco           (distancia 1132)
# Real salta           predijo tucuman         (distancia 228)
# Real catamarca       predijo chubut          (distancia 1647)
# Real santafe         predijo chaco           (distancia 495)
# Real cordoba         predijo tucuman         (distancia 517)
# Real santacruz       predijo chubut          (distancia 975)
# Real santiago        predijo sanjuan         (distancia 583)
# Real larioja         predijo mendoza         (distancia 427)
# Real salta           predijo catamarca       (distancia 410)
# Real cordoba         predijo formosa         (distancia 824)
# Real lapampa         predijo santafe         (distancia 641)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real larioja         predijo santafe         (distancia 640)
# Real neuquen         predijo chaco           (distancia 1529)
# Real santacruz       predijo salta           (distancia 2997)
# Real salta           predijo misiones        (distancia 992)
# Real tierradelfuego  predijo sanjuan         (distancia 2585)
# Real formosa         predijo santafe         (distancia 654)
# Real cordoba         predijo larioja         (distancia 340)
# Real salta           predijo lapampa         (distancia 1316)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real entrerios       predijo chaco           (distancia 498)
# Real buenosaires     predijo tierradelfuego  (distancia 2373)
# Real entrerios       predijo chubut          (distancia 1345)
# Real lapampa         predijo formosa         (distancia 1293)
# Real tierradelfuego  predijo cordoba         (distancia 2618)
# Real chaco           predijo misiones        (distancia 305)
# Real santiago        predijo tucuman         (distancia 141)
# Real buenosaires     predijo sanluis         (distancia 749)
# Real jujuy           predijo rionegro        (distancia 1855)
# Real larioja         predijo santafe         (distancia 640)
# Real lapampa         predijo mendoza         (distancia 586)
# Real cordoba         predijo larioja         (distancia 340)
# Real rionegro        predijo lapampa         (distancia 477)
# Real catamarca       predijo larioja         (distancia 149)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real salta           predijo santiago        (distancia 353)
# Real misiones        predijo chaco           (distancia 305)
# Real salta           predijo jujuy           (distancia 67)
# Real sanjuan         predijo larioja         (distancia 283)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real cordoba         predijo chubut          (distancia 1321)
# Real buenosaires     predijo rionegro        (distancia 799)
# Real catamarca       predijo larioja         (distancia 149)
# Real chubut          predijo santafe         (distancia 1349)
# Real salta           predijo tucuman         (distancia 228)
# Real mendoza         predijo sanjuan         (distancia 152)
# Real corrientes      predijo chaco           (distancia 13)
# Real larioja         predijo tucuman         (distancia 330)
# Real jujuy           predijo salta           (distancia 67)
# Real tucuman         predijo corrientes      (distancia 633)
# Real formosa         predijo chaco           (distancia 161)
# Real buenosaires     predijo santafe         (distancia 393)
# Real salta           predijo santiago        (distancia 353)
# Real sanluis         predijo chubut          (distancia 1113)
# Real tucuman         predijo jujuy           (distancia 293)
# Real lapampa         predijo chaco           (distancia 1132)
# Real catamarca       predijo cordoba         (distancia 362)
# Real neuquen         predijo sanluis         (distancia 643)
# Real tucuman         predijo jujuy           (distancia 293)
# Real entrerios       predijo chaco           (distancia 498)
# Real corrientes      predijo formosa         (distancia 157)
# Real tucuman         predijo santafe         (distancia 689)
# Real santacruz       predijo santafe         (distancia 2325)
# Real lapampa         predijo chaco           (distancia 1132)
# Real formosa         predijo chaco           (distancia 161)
# Real buenosaires     predijo misiones        (distancia 834)
# Real santacruz       predijo chaco           (distancia 2818)
# Real salta           predijo tucuman         (distancia 228)
# Real misiones        predijo corrientes      (distancia 291)
# Real sanjuan         predijo cordoba         (distancia 412)
# Real sanjuan         predijo santiago        (distancia 583)
# Real tierradelfuego  predijo formosa         (distancia 3284)
# Real misiones        predijo corrientes      (distancia 291)
# Real santacruz       predijo sanjuan         (distancia 2231)
# Real entrerios       predijo chaco           (distancia 498)
# Real santiago        predijo tucuman         (distancia 141)
# Real chaco           predijo corrientes      (distancia 13)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real santacruz       predijo chaco           (distancia 2818)
# Real entrerios       predijo sanjuan         (distancia 757)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real cordoba         predijo santafe         (distancia 330)
# Real sanluis         predijo misiones        (distancia 1200)
# Real santafe         predijo lapampa         (distancia 641)
# Real tierradelfuego  predijo sanjuan         (distancia 2585)
# Real formosa         predijo santafe         (distancia 654)
# Real buenosaires     predijo santiago        (distancia 939)
# Real lapampa         predijo cordoba         (distancia 577)
# Real chaco           predijo misiones        (distancia 305)
# Real entrerios       predijo formosa         (distancia 656)
# Real rionegro        predijo chaco           (distancia 1526)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real salta           predijo tucuman         (distancia 228)
# Real santacruz       predijo corrientes      (distancia 2819)
# Real buenosaires     predijo chaco           (distancia 794)
# Real jujuy           predijo buenosaires     (distancia 1334)
# Real tierradelfuego  predijo rionegro        (distancia 1605)
# Real corrientes      predijo formosa         (distancia 157)
# Real rionegro        predijo chaco           (distancia 1526)
# Real buenosaires     predijo tierradelfuego  (distancia 2373)
# Real santacruz       predijo chubut          (distancia 975)
# Real jujuy           predijo tucuman         (distancia 293)
# Real mendoza         predijo formosa         (distancia 1269)
# Real larioja         predijo santiago        (distancia 311)
# Real cordoba         predijo santacruz       (distancia 2281)
# Real santafe         predijo santacruz       (distancia 2325)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real formosa         predijo chaco           (distancia 161)
# Real lapampa         predijo mendoza         (distancia 586)
# Real lapampa         predijo chaco           (distancia 1132)
# Real mendoza         predijo entrerios       (distancia 790)
# Real mendoza         predijo sanjuan         (distancia 152)
# Real cordoba         predijo larioja         (distancia 340)
# Real rionegro        predijo entrerios       (distancia 1030)
# Real buenosaires     predijo mendoza         (distancia 985)
# Real santacruz       predijo neuquen         (distancia 1410)
# Real tucuman         predijo jujuy           (distancia 293)
# Real salta           predijo jujuy           (distancia 67)
# Real entrerios       predijo chaco           (distancia 498)
# Real santiago        predijo jujuy           (distancia 414)
# Real santafe         predijo formosa         (distancia 654)
# Real entrerios       predijo mendoza         (distancia 790)
# Real santiago        predijo chubut          (distancia 1721)
# Real lapampa         predijo chaco           (distancia 1132)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real jujuy           predijo tucuman         (distancia 293)
# Real sanjuan         predijo neuquen         (distancia 824)
# Real tucuman         predijo rionegro        (distancia 1562)
# Real tierradelfuego  predijo formosa         (distancia 3284)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real santiago        predijo santafe         (distancia 547)
# Real lapampa         predijo neuquen         (distancia 422)
# Real tierradelfuego  predijo jujuy           (distancia 3408)
# Real lapampa         predijo sanluis         (distancia 412)
# Real lapampa         predijo formosa         (distancia 1293)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real buenosaires     predijo rionegro        (distancia 799)
# Real corrientes      predijo formosa         (distancia 157)
# Real neuquen         predijo chaco           (distancia 1529)
# Real neuquen         predijo santafe         (distancia 1049)
# Real entrerios       predijo sanluis         (distancia 574)
# Real santafe         predijo chaco           (distancia 495)
# Real jujuy           predijo tucuman         (distancia 293)
# Real chaco           predijo formosa         (distancia 161)
# Real jujuy           predijo larioja         (distancia 600)
# Real lapampa         predijo salta           (distancia 1316)
# Real tucuman         predijo entrerios       (distancia 707)
# Real jujuy           predijo tucuman         (distancia 293)
# Real santiago        predijo misiones        (distancia 827)
# Real sanluis         predijo santiago        (distancia 643)
# Real sanluis         predijo sanjuan         (distancia 284)
# Real corrientes      predijo formosa         (distancia 157)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real buenosaires     predijo corrientes      (distancia 792)
# Real santafe         predijo chaco           (distancia 495)
# Real salta           predijo tucuman         (distancia 228)
# Real lapampa         predijo sanjuan         (distancia 686)
# Real santafe         predijo buenosaires     (distancia 393)
# Real catamarca       predijo larioja         (distancia 149)
# Real cordoba         predijo larioja         (distancia 340)
# Real tucuman         predijo chubut          (distancia 1827)
# Real larioja         predijo tierradelfuego  (distancia 2821)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real buenosaires     predijo rionegro        (distancia 799)
# Real sanjuan         predijo catamarca       (distancia 430)
# Real santacruz       predijo chubut          (distancia 975)
# Real formosa         predijo chaco           (distancia 161)
# Real buenosaires     predijo formosa         (distancia 933)
# Real salta           predijo jujuy           (distancia 67)
# Real formosa         predijo jujuy           (distancia 750)
# Real santafe         predijo entrerios       (distancia 19)
# Real jujuy           predijo misiones        (distancia 1007)
# Real rionegro        predijo chaco           (distancia 1526)
# Real catamarca       predijo sanjuan         (distancia 430)
# Real santafe         predijo chaco           (distancia 495)
# Real catamarca       predijo santiago        (distancia 166)
# Real santafe         predijo catamarca       (distancia 602)
# Real formosa         predijo misiones        (distancia 263)
# Real rionegro        predijo cordoba         (distancia 1047)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real larioja         predijo santafe         (distancia 640)
# Real rionegro        predijo neuquen         (distancia 479)
# Real neuquen         predijo sanjuan         (distancia 824)
# Real chaco           predijo misiones        (distancia 305)
# Real chaco           predijo corrientes      (distancia 13)
# Real santiago        predijo tucuman         (distancia 141)
# Real santiago        predijo chaco           (distancia 523)
# Real santafe         predijo formosa         (distancia 654)
# Real salta           predijo santafe         (distancia 889)
# Real lapampa         predijo mendoza         (distancia 586)
# Real santiago        predijo chaco           (distancia 523)
# Real lapampa         predijo chaco           (distancia 1132)
# Real corrientes      predijo misiones        (distancia 291)
# Real mendoza         predijo larioja         (distancia 427)
# Real buenosaires     predijo entrerios       (distancia 375)
# Real lapampa         predijo chubut          (distancia 745)
# Real salta           predijo larioja         (distancia 533)
# Real buenosaires     predijo rionegro        (distancia 799)
# Real buenosaires     predijo santafe         (distancia 393)
# Real neuquen         predijo chaco           (distancia 1529)
# Real corrientes      predijo misiones        (distancia 291)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real sanluis         predijo sanjuan         (distancia 284)
# Real mendoza         predijo sanluis         (distancia 235)
# Real sanluis         predijo cordoba         (distancia 293)
# Real lapampa         predijo chaco           (distancia 1132)
# Real santacruz       predijo santiago        (distancia 2677)
# Real sanluis         predijo rionegro        (distancia 882)
# Real rionegro        predijo neuquen         (distancia 479)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real rionegro        predijo neuquen         (distancia 479)
# Real santacruz       predijo entrerios       (distancia 2320)
# Real santafe         predijo misiones        (distancia 664)
# Real catamarca       predijo tucuman         (distancia 189)
# Real sanjuan         predijo mendoza         (distancia 152)
# Real jujuy           predijo tucuman         (distancia 293)
# Real mendoza         predijo rionegro        (distancia 1019)
# Real catamarca       predijo larioja         (distancia 149)
# Real formosa         predijo corrientes      (distancia 157)
# Real entrerios       predijo tierradelfuego  (distancia 2635)
# Real jujuy           predijo tucuman         (distancia 293)
# Real tucuman         predijo jujuy           (distancia 293)
# Real catamarca       predijo chubut          (distancia 1647)
# Real buenosaires     predijo corrientes      (distancia 792)
# Real sanluis         predijo mendoza         (distancia 235)
# Real lapampa         predijo neuquen         (distancia 422)
# Real salta           predijo formosa         (distancia 741)
# Real tucuman         predijo santafe         (distancia 689)
# Real chaco           predijo santafe         (distancia 495)
# Real lapampa         predijo chaco           (distancia 1132)
# Real mendoza         predijo chubut          (distancia 1201)
# Real mendoza         predijo neuquen         (distancia 676)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real neuquen         predijo chaco           (distancia 1529)
# Real neuquen         predijo sanjuan         (distancia 824)
# Real mendoza         predijo lapampa         (distancia 586)
# Real mendoza         predijo santafe         (distancia 775)
# Real larioja         predijo catamarca       (distancia 149)
# Real buenosaires     predijo rionegro        (distancia 799)
# Real cordoba         predijo jujuy           (distancia 809)
# Real larioja         predijo santacruz       (distancia 2471)
# Real cordoba         predijo mendoza         (distancia 466)
# Real misiones        predijo santafe         (distancia 664)
# Real jujuy           predijo tucuman         (distancia 293)
# Real chubut          predijo santafe         (distancia 1349)
# Real santafe         predijo rionegro        (distancia 1035)
# Real salta           predijo tucuman         (distancia 228)
# Real catamarca       predijo jujuy           (distancia 477)
# Real chaco           predijo formosa         (distancia 161)
# Real chaco           predijo corrientes      (distancia 13)
# Real rionegro        predijo chaco           (distancia 1526)
# Real santiago        predijo santafe         (distancia 547)
# Real santacruz       predijo misiones        (distancia 2914)
# Real tucuman         predijo santacruz       (distancia 2773)
# Real santafe         predijo santiago        (distancia 547)
# Real lapampa         predijo santafe         (distancia 641)
# Real tierradelfuego  predijo santafe         (distancia 2641)
# Real sanluis         predijo santiago        (distancia 643)
# Real misiones        predijo lapampa         (distancia 1293)
# Real sanjuan         predijo formosa         (distancia 1169)
# Real tierradelfuego  predijo santafe         (distancia 2641)
# Real santacruz       predijo santafe         (distancia 2325)
# Real tierradelfuego  predijo misiones        (distancia 3207)
# Real misiones        predijo chaco           (distancia 305)
# Real santiago        predijo tucuman         (distancia 141)
# Real santiago        predijo tucuman         (distancia 141)
# Real sanluis         predijo larioja         (distancia 435)
# Real salta           predijo tucuman         (distancia 228)
# Real jujuy           predijo tucuman         (distancia 293)
# Real santacruz       predijo santafe         (distancia 2325)
# Real jujuy           predijo santafe         (distancia 942)
# Real tucuman         predijo santafe         (distancia 689)
# Real corrientes      predijo salta           (distancia 719)
# Real salta           predijo cordoba         (distancia 745)
# Real rionegro        predijo santafe         (distancia 1035)
# Real catamarca       predijo santafe         (distancia 602)
# Real sanjuan         predijo larioja         (distancia 283)
# Real lapampa         predijo misiones        (distancia 1293)
# Real corrientes      predijo santafe         (distancia 498)
# Real cordoba         predijo santafe         (distancia 330)
# Real chubut          predijo rionegro        (distancia 327)
# Real entrerios       predijo santafe         (distancia 19)
# Real mendoza         predijo sanjuan         (distancia 152)
# Real entrerios       predijo corrientes      (distancia 500)
# Real tierradelfuego  predijo misiones        (distancia 3207)
# Real larioja         predijo sanjuan         (distancia 283)
# Real jujuy           predijo santafe         (distancia 942)
# Real sanluis         predijo sanjuan         (distancia 284)
# Real lapampa         predijo chaco           (distancia 1132)
# Real santiago        predijo tucuman         (distancia 141)
# Real rionegro        predijo santafe         (distancia 1035)
# Real entrerios       predijo santafe         (distancia 19)
# Real formosa         predijo santafe         (distancia 654)
# Real salta           predijo tucuman         (distancia 228)
# Real sanjuan         predijo cordoba         (distancia 412)
# Real buenosaires     predijo formosa         (distancia 933)
# Real rionegro        predijo chaco           (distancia 1526)
# Real larioja         predijo mendoza         (distancia 427)
# Real sanjuan         predijo santafe         (distancia 740)
# Real santiago        predijo salta           (distancia 353)
# Real buenosaires     predijo entrerios       (distancia 375)
# Real catamarca       predijo salta           (distancia 410)
# Real sanluis         predijo chaco           (distancia 961)
# Real lapampa         predijo santafe         (distancia 641)
# Real chubut          predijo santafe         (distancia 1349)
# Real formosa         predijo santafe         (distancia 654)
# Real santacruz       predijo sanluis         (distancia 2046)
# Real lapampa         predijo chaco           (distancia 1132)
# Real chaco           predijo formosa         (distancia 161)
# Real catamarca       predijo chaco           (distancia 678)
# Real lapampa         predijo santafe         (distancia 641)
# Real larioja         predijo santafe         (distancia 640)
# Real santiago        predijo santafe         (distancia 547)
# Real jujuy           predijo santafe         (distancia 942)
# Real cordoba         predijo chubut          (distancia 1321)
# Real santiago        predijo formosa         (distancia 629)
# Real sanjuan         predijo larioja         (distancia 283)
# Real entrerios       predijo santafe         (distancia 19)
# Real lapampa         predijo corrientes      (distancia 1136)
# Real sanjuan         predijo santafe         (distancia 740)
# Real chaco           predijo santafe         (distancia 495)
# Real catamarca       predijo santafe         (distancia 602)
# Real rionegro        predijo buenosaires     (distancia 799)
# Real lapampa         predijo chaco           (distancia 1132)
# Real santacruz       predijo santafe         (distancia 2325)
# Real salta           predijo mendoza         (distancia 957)
# Real salta           predijo tucuman         (distancia 228)
# Real corrientes      predijo santafe         (distancia 498)
# Real formosa         predijo misiones        (distancia 263)
# Real santiago        predijo santafe         (distancia 547)
# Real chaco           predijo corrientes      (distancia 13)
# Real tierradelfuego  predijo santafe         (distancia 2641)
# Real misiones        predijo santafe         (distancia 664)
# Real cordoba         predijo buenosaires     (distancia 646)
# Real cordoba         predijo sanjuan         (distancia 412)
# Real santacruz       predijo tucuman         (distancia 2773)
# Real buenosaires     predijo chaco           (distancia 794)
# Real santacruz       predijo santafe         (distancia 2325)
# Real entrerios       predijo santafe         (distancia 19)
# Real santacruz       predijo tierradelfuego  (distancia 359)
# Real larioja         predijo santafe         (distancia 640)
# Real jujuy           predijo santafe         (distancia 942)
# Real jujuy           predijo santafe         (distancia 942)
# Real catamarca       predijo tucuman         (distancia 189)
# Real santiago        predijo chaco           (distancia 523)
# Real salta           predijo santafe         (distancia 889)
# Real catamarca       predijo tierradelfuego  (distancia 2931)
# Real jujuy           predijo tucuman         (distancia 293)
# Real sanluis         predijo santafe         (distancia 560)
# Real buenosaires     predijo santafe         (distancia 393)
# Real corrientes      predijo cordoba         (distancia 677)
# Real catamarca       predijo santafe         (distancia 602)
# Real chubut          predijo lapampa         (distancia 745)
# Real salta           predijo sanluis         (distancia 950)
# Real santiago        predijo santafe         (distancia 547)
# Real larioja         predijo santafe         (distancia 640)
# Real tierradelfuego  predijo santafe         (distancia 2641)
# Real chaco           predijo santafe         (distancia 495)
# Real salta           predijo santafe         (distancia 889)
# Real misiones        predijo formosa         (distancia 263)
# Real sanluis         predijo santafe         (distancia 560)
# Real sanjuan         predijo santafe         (distancia 740)
# Real sanjuan         predijo tucuman         (distancia 612)
# Real buenosaires     predijo salta           (distancia 1282)
# Real santafe         predijo jujuy           (distancia 942)
# Real lapampa         predijo santafe         (distancia 641)
# Real sanluis         predijo jujuy           (distancia 1017)
# Real cordoba         predijo santafe         (distancia 330)
# Real sanluis         predijo santafe         (distancia 560)
# Real tierradelfuego  predijo santafe         (distancia 2641)
# Real corrientes      predijo santafe         (distancia 498)
# Real chaco           predijo santafe         (distancia 495)
# Real sanluis         predijo formosa         (distancia 1117)
# Real neuquen         predijo santafe         (distancia 1049)
# Real salta           predijo formosa         (distancia 741)
# Real larioja         predijo santafe         (distancia 640)
# Real santacruz       predijo santafe         (distancia 2325)
# Real sanluis         predijo santafe         (distancia 560)
# Real santiago        predijo santafe         (distancia 547)
# Real santacruz       predijo santafe         (distancia 2325)
# Real santiago        predijo santafe         (distancia 547)
# Real catamarca       predijo santafe         (distancia 602)
# Real cordoba         predijo santiago        (distancia 401)
# Real mendoza         predijo santafe         (distancia 775)
# Real santacruz       predijo santafe         (distancia 2325)
# Real formosa         predijo santafe         (distancia 654)
# Real santacruz       predijo santafe         (distancia 2325)
# Real formosa         predijo santafe         (distancia 654)
# Real mendoza         predijo santafe         (distancia 775)
# Real buenosaires     predijo santacruz       (distancia 2082)
# Real misiones        predijo santafe         (distancia 664)
# Real buenosaires     predijo santafe         (distancia 393)
# Real chaco           predijo formosa         (distancia 161)
# Real larioja         predijo salta           (distancia 533)
# Real larioja         predijo santafe         (distancia 640)
# Real santacruz       predijo santafe         (distancia 2325)
# Real sanjuan         predijo santafe         (distancia 740)
# Real rionegro        predijo formosa         (distancia 1681)
# Real formosa         predijo santafe         (distancia 654)
# Real santiago        predijo santafe         (distancia 547)
# Real sanluis         predijo santafe         (distancia 560)
# Real formosa         predijo santafe         (distancia 654)
# Real tucuman         predijo santafe         (distancia 689)
# Real santacruz       predijo santafe         (distancia 2325)
# Real corrientes      predijo santafe         (distancia 498)
# Real larioja         predijo chubut          (distancia 1548)
# Real misiones        predijo corrientes      (distancia 291)
# Real mendoza         predijo santafe         (distancia 775)
# Real rionegro        predijo jujuy           (distancia 1855)
# Real chaco           predijo santafe         (distancia 495)
# Real catamarca       predijo santafe         (distancia 602)
# Real santiago        predijo tucuman         (distancia 141)
# Real salta           predijo cordoba         (distancia 745)
# Real jujuy           predijo santafe         (distancia 942)
# Real sanjuan         predijo santafe         (distancia 740)
# Real santiago        predijo santafe         (distancia 547)
# Real formosa         predijo santafe         (distancia 654)
# Real salta           predijo santafe         (distancia 889)
# Real sanluis         predijo santafe         (distancia 560)
# Real sanluis         predijo corrientes      (distancia 969)
# Real tucuman         predijo santafe         (distancia 689)
# Real cordoba         predijo catamarca       (distancia 362)
# Real tucuman         predijo larioja         (distancia 330)
# Real sanjuan         predijo santafe         (distancia 740)
# Real salta           predijo corrientes      (distancia 719)
# Real tucuman         predijo santiago        (distancia 141)
# Real salta           predijo tucuman         (distancia 228)
# Real lapampa         predijo chaco           (distancia 1132)
# Real buenosaires     predijo lapampa         (distancia 579)
# Real tucuman         predijo santafe         (distancia 689)
# Real santacruz       predijo chubut          (distancia 975)
# Real tucuman         predijo catamarca       (distancia 189)
# Real cordoba         predijo chubut          (distancia 1321)
# Real corrientes      predijo entrerios       (distancia 500)
# Real rionegro        predijo cordoba         (distancia 1047)
# Real jujuy           predijo tucuman         (distancia 293)
# Real formosa         predijo santafe         (distancia 654)
# Real jujuy           predijo misiones        (distancia 1007)
# Real buenosaires     predijo larioja         (distancia 986)
# Real chaco           predijo corrientes      (distancia 13)
# Real buenosaires     predijo larioja         (distancia 986)
# Real buenosaires     predijo chaco           (distancia 794)
# Real tierradelfuego  predijo santacruz       (distancia 359)
# Real santacruz       predijo chubut          (distancia 975)
# Real salta           predijo santiago        (distancia 353)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))
cm = confusion_matrix(real_prov, pred_prov)


df_cm = pd.DataFrame(cm, index=province_encoder.classes_, columns=province_encoder.classes_)

sns.heatmap(df_cm)

# %% [markdown]
# 2500 palabras dan un accuracy de 71%. BASTANTE BIEN. Luego disminuye la performance
